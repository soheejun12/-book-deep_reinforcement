# %% [markdown]
# ### - FrozenLake에서 Cross-entropy를 사용하여 해결하는 방법
# - 사용하는 에피소드의 배치 개수 늘리기
#     - CartPole 16개 사용
#     - FrozenLake 최소 100개 사용 필요
#
#
# - 보상에 할인계수 적용
#     - 총보상을 에피소드의 길이에 의존하도록 만들고 에피소드의 다양성을 더하기 위해 할인계수 사용
#     - 0.9 혹은 0.95
#     - 더 짧은 에피소드가 긴 에피소드 보다 더 높은 보상을 얻게 됨
#
#
# - 엘리트 에피소드를 더 오래 유지하기
#     - Cartpole, 환경에서 에피소드를 샘플링하고 좋은 것들에 대해 학습한 후 버림
#     - FrozenLake, 성공 에피소드가 훨씬 드물어서 그 에피소드에 대해 여러번 반복하여 학습
#
#
# - 학습률 낮추기
#     - 네트워크 시간을 더 많은 훈련 견본 평균에 줄 것
#
#
# - 학습 시간 늘리기
#     - 성공 에피소드가 드물고 액션의 무작위성 때문에, 네트워크는 특정 상황에서 최선의 행동을 깨닫기가 어려움
#     - 50% 성공 에피소드를 달성하기 위해 5000번의 반복 학습이 요구됨

# %% [markdown]
# #### - 코드 수정
# - filter_batch() 함수 수정
#     - 할인 보상 설정
#     - 엘리트 에피소드 유지
#
#
# - training loop
#     - 현재의 엘리트 에피소드를 저장하여 다음 학습 반복의 이전 함수에 전달
#
#
# - 학습률 10배 줄임
#
#
# - BATCH_SIZE = 100

# %%
import random
import gym
import gym.spaces
from collections import namedtuple
import numpy as np
from tensorboardX import SummaryWriter
import torch
import torch.nn as nn
import torch.optim as optim

# %%
HIDDEN_SIZE = 128
BATCH_SIZE = 100 
PERCENTILE = 30
GAMMA = 0.9  #discount factor

# %%
class DiscreteOneHotWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super(DiscreteOneHotWrapper, self).__init__(env)
        assert isinstance(env.observation_space, gym.spaces.Discrete)
        
        self.observation_space = gym.spaces.Box(0.0, 1.0, (env.observation_space.n, ), dtype=np.float32)
        
    
    def observation(self, observation):
        res = np.copy(self.observation_space.low)
        res[observation] = 1.0
        
        return res

# %%
class Net(nn.Module):
    def __init__(self, obs_size, hidden_size, n_actions):
        super(Net, self).__init__()
        
        self.net = nn.Sequential(nn.Linear(obs_size, hidden_size), 
                                 nn.ReLU(),
                                 nn.Linear(hidden_size, n_actions))
        
    def forward(self, x):
        return self.net(x)

# %%
Episode = namedtuple('Episode', field_names=['reward', 'steps'])
EpisodeStep = namedtuple('EpisodeStep', field_names=['observation', 'action'])

# %%
def iterate_batches(env, net, batch_size):
    batch = []
    episode_reward = 0.0
    episode_steps = []
    obs = env.reset()
    
    sm = nn.Softmax(dim=1)
    
    while True :
        obs_v = torch.FloatTensor([obs])
        act_probs_v = sm(net(obs_v))
        act_probs = act_probs_v.data.numpy()[0]
        action = np.random.choice(len(act_probs), p=act_probs)
        
        next_obs, reward, is_done, _ = env.step(action)
        
        #env.render()
        
        episode_reward += reward 
        episode_steps.append(EpisodeStep(observation=obs, action=action))
        
        
        if is_done :
            batch.append(Episode(reward=episode_reward, steps=episode_steps))
            
            episode_reward = 0.0
            episode_steps = []
            next_obs = env.reset()
            
            if len(batch) == batch_size :
                yield batch
                batch = []
                
        obs = next_obs

# %%
def filter_batch(batch, percentile):
    """discounted rewards"""
    disc_rewards = list(map(lambda s : s.reward * (GAMMA ** len(s.steps)), batch)) ###
    
    reward_bound = np.percentile(disc_rewards, percentile)
    
    train_obs = []
    train_act = []
    elite_batch = []
    
    for example, discounted_reward in zip(batch, disc_rewards):
        if discounted_reward > reward_bound :
            train_obs.extend(map(lambda step : step.observation, example.steps))
            train_act.extend(map(lambda step : step.action, example.steps))
            elite_batch.append(example)
            
    return elite_batch, train_obs, train_act, reward_bound

# %%
if __name__ == "__main__":
    random.seed(12345)
    
    env = DiscreteOneHotWrapper(gym.make("FrozenLake-v0"))
    #env = gym.wrappers.Monitor(env, directory="mon", force=True)
    
    obs_size = env.observation_space.shape[0]
    n_actions = env.action_space.n 
    
    net = Net(obs_size, HIDDEN_SIZE, n_actions)
    
    objective = nn.CrossEntropyLoss()
    
    optimizer = optim.Adam(params=net.parameters(), lr=0.001)
    
    writer = SummaryWriter(comment="-frozenlake-tweaked")
    
    
    full_batch = []
    
    for iter_no, batch in enumerate(iterate_batches(env, net, BATCH_SIZE)):
        reward_mean = float(np.mean(list(map(lambda s : s.reward, batch))))
        
        full_batch, obs, acts, reward_bound = filter_batch(full_batch + batch, PERCENTILE)
        
        if not full_batch :
            continue
            
        obs_v = torch.FloatTensor(obs)
        acts_v = torch.LongTensor(acts)
        
        full_batch = full_batch[-500:] ####
        
        optimizer.zero_grad()
        
        action_scores_v = net(obs_v)
        loss_v = objective(action_scores_v, acts_v)
        loss_v.backward()
        
        optimizer.step()
        
        print("%d: loss=%.3f, reward_mean=%.3f, reward_bound=%.3f, batch=%d" % (
               iter_no, loss_v.item(), reward_mean, reward_bound, len(full_batch)))
        writer.add_scalar("loss", loss_v.item(), iter_no)
        writer.add_scalar("reward_mean", reward_mean, iter_no)
        writer.add_scalar("reward_bound", reward_bound, iter_no)
        
        if reward_mean > 0.8:
            print("Solved!")
            break
            
    writer.close()
# Out:
# 0: loss=1.386, reward_mean=0.030, reward_bound=0.000, batch=3
# 1: loss=1.378, reward_mean=0.010, reward_bound=0.000, batch=4
# 2: loss=1.375, reward_mean=0.000, reward_bound=0.000, batch=4
# 3: loss=1.378, reward_mean=0.030, reward_bound=0.000, batch=7
# 4: loss=1.377, reward_mean=0.020, reward_bound=0.000, batch=9
# 5: loss=1.376, reward_mean=0.000, reward_bound=0.000, batch=9
# 6: loss=1.374, reward_mean=0.020, reward_bound=0.000, batch=11
# 7: loss=1.374, reward_mean=0.010, reward_bound=0.000, batch=12
# 8: loss=1.372, reward_mean=0.000, reward_bound=0.000, batch=12
# 9: loss=1.372, reward_mean=0.010, reward_bound=0.000, batch=13
# 10: loss=1.374, reward_mean=0.020, reward_bound=0.000, batch=15
# 11: loss=1.366, reward_mean=0.020, reward_bound=0.000, batch=17
# 12: loss=1.365, reward_mean=0.020, reward_bound=0.000, batch=19
# 13: loss=1.369, reward_mean=0.030, reward_bound=0.000, batch=22
# 14: loss=1.369, reward_mean=0.020, reward_bound=0.000, batch=24
# 15: loss=1.363, reward_mean=0.020, reward_bound=0.000, batch=26
# 16: loss=1.360, reward_mean=0.030, reward_bound=0.000, batch=29
# 17: loss=1.358, reward_mean=0.020, reward_bound=0.000, batch=31
# 18: loss=1.356, reward_mean=0.020, reward_bound=0.000, batch=33
# 19: loss=1.354, reward_mean=0.010, reward_bound=0.000, batch=34
# 20: loss=1.355, reward_mean=0.030, reward_bound=0.000, batch=37
# 21: loss=1.355, reward_mean=0.010, reward_bound=0.000, batch=38
# 22: loss=1.355, reward_mean=0.010, reward_bound=0.000, batch=39
# 23: loss=1.356, reward_mean=0.060, reward_bound=0.000, batch=45
# 24: loss=1.357, reward_mean=0.030, reward_bound=0.000, batch=48
# 25: loss=1.356, reward_mean=0.030, reward_bound=0.000, batch=51
# 26: loss=1.356, reward_mean=0.010, reward_bound=0.000, batch=52
# 27: loss=1.355, reward_mean=0.020, reward_bound=0.000, batch=54
# 28: loss=1.357, reward_mean=0.040, reward_bound=0.000, batch=58
# 29: loss=1.353, reward_mean=0.040, reward_bound=0.000, batch=62
# 30: loss=1.349, reward_mean=0.020, reward_bound=0.000, batch=64
# 31: loss=1.348, reward_mean=0.000, reward_bound=0.000, batch=64
# 32: loss=1.348, reward_mean=0.020, reward_bound=0.000, batch=66
# 33: loss=1.346, reward_mean=0.050, reward_bound=0.000, batch=71
# 34: loss=1.345, reward_mean=0.020, reward_bound=0.000, batch=73
# 35: loss=1.345, reward_mean=0.020, reward_bound=0.000, batch=75
# 36: loss=1.346, reward_mean=0.030, reward_bound=0.000, batch=78
# 37: loss=1.346, reward_mean=0.020, reward_bound=0.000, batch=80
# 38: loss=1.344, reward_mean=0.020, reward_bound=0.000, batch=82
# 39: loss=1.342, reward_mean=0.020, reward_bound=0.000, batch=84
# 40: loss=1.341, reward_mean=0.010, reward_bound=0.000, batch=85
# 41: loss=1.341, reward_mean=0.030, reward_bound=0.000, batch=88
# 42: loss=1.339, reward_mean=0.010, reward_bound=0.000, batch=89
# 43: loss=1.339, reward_mean=0.000, reward_bound=0.000, batch=89
# 44: loss=1.339, reward_mean=0.040, reward_bound=0.000, batch=93
# 45: loss=1.338, reward_mean=0.010, reward_bound=0.000, batch=94
# 46: loss=1.338, reward_mean=0.030, reward_bound=0.000, batch=97
# 47: loss=1.337, reward_mean=0.020, reward_bound=0.000, batch=99
# 48: loss=1.336, reward_mean=0.010, reward_bound=0.000, batch=100
# 49: loss=1.336, reward_mean=0.010, reward_bound=0.000, batch=101
# 50: loss=1.337, reward_mean=0.010, reward_bound=0.000, batch=102
# 51: loss=1.336, reward_mean=0.010, reward_bound=0.000, batch=103
# 52: loss=1.336, reward_mean=0.000, reward_bound=0.000, batch=103
# 53: loss=1.335, reward_mean=0.030, reward_bound=0.000, batch=106
# 54: loss=1.335, reward_mean=0.030, reward_bound=0.000, batch=109
# 55: loss=1.334, reward_mean=0.030, reward_bound=0.000, batch=112
# 56: loss=1.332, reward_mean=0.030, reward_bound=0.000, batch=115
# 57: loss=1.331, reward_mean=0.030, reward_bound=0.000, batch=118
# 58: loss=1.330, reward_mean=0.000, reward_bound=0.000, batch=118
# 59: loss=1.330, reward_mean=0.070, reward_bound=0.000, batch=125
# 60: loss=1.330, reward_mean=0.040, reward_bound=0.000, batch=129
# 61: loss=1.330, reward_mean=0.000, reward_bound=0.000, batch=129
# 62: loss=1.330, reward_mean=0.000, reward_bound=0.000, batch=129
# 63: loss=1.328, reward_mean=0.030, reward_bound=0.000, batch=132
# 64: loss=1.327, reward_mean=0.040, reward_bound=0.000, batch=136
# 65: loss=1.326, reward_mean=0.030, reward_bound=0.000, batch=139
# 66: loss=1.325, reward_mean=0.030, reward_bound=0.000, batch=142
# 67: loss=1.324, reward_mean=0.020, reward_bound=0.000, batch=144
# 68: loss=1.324, reward_mean=0.000, reward_bound=0.000, batch=144
# 69: loss=1.322, reward_mean=0.040, reward_bound=0.000, batch=148
# 70: loss=1.321, reward_mean=0.040, reward_bound=0.000, batch=152
# 71: loss=1.320, reward_mean=0.010, reward_bound=0.000, batch=153
# 72: loss=1.319, reward_mean=0.040, reward_bound=0.000, batch=157
# 73: loss=1.318, reward_mean=0.020, reward_bound=0.000, batch=159
# 74: loss=1.317, reward_mean=0.020, reward_bound=0.000, batch=161
# 75: loss=1.315, reward_mean=0.020, reward_bound=0.000, batch=163
# 76: loss=1.314, reward_mean=0.020, reward_bound=0.000, batch=165
# 77: loss=1.313, reward_mean=0.010, reward_bound=0.000, batch=166
# 78: loss=1.313, reward_mean=0.020, reward_bound=0.000, batch=168
# 79: loss=1.311, reward_mean=0.030, reward_bound=0.000, batch=171
# 80: loss=1.311, reward_mean=0.030, reward_bound=0.000, batch=174
# 81: loss=1.308, reward_mean=0.030, reward_bound=0.000, batch=177
# 82: loss=1.308, reward_mean=0.020, reward_bound=0.000, batch=179
# 83: loss=1.307, reward_mean=0.020, reward_bound=0.000, batch=181
# 84: loss=1.305, reward_mean=0.070, reward_bound=0.000, batch=188
# 85: loss=1.304, reward_mean=0.050, reward_bound=0.000, batch=193
# 86: loss=1.303, reward_mean=0.020, reward_bound=0.000, batch=195
# 87: loss=1.302, reward_mean=0.020, reward_bound=0.000, batch=197
# 88: loss=1.302, reward_mean=0.030, reward_bound=0.000, batch=200
# 89: loss=1.299, reward_mean=0.090, reward_bound=0.000, batch=209
# 90: loss=1.298, reward_mean=0.020, reward_bound=0.000, batch=211
# 91: loss=1.297, reward_mean=0.030, reward_bound=0.000, batch=214
# 92: loss=1.297, reward_mean=0.020, reward_bound=0.000, batch=216
# 93: loss=1.297, reward_mean=0.040, reward_bound=0.000, batch=220
# 94: loss=1.296, reward_mean=0.020, reward_bound=0.000, batch=222
# 95: loss=1.297, reward_mean=0.010, reward_bound=0.000, batch=223
# 96: loss=1.296, reward_mean=0.030, reward_bound=0.019, batch=226
# 97: loss=1.290, reward_mean=0.050, reward_bound=0.045, batch=228
# 98: loss=1.288, reward_mean=0.040, reward_bound=0.052, batch=228
# 99: loss=1.286, reward_mean=0.060, reward_bound=0.080, batch=228
# 100: loss=1.279, reward_mean=0.070, reward_bound=0.111, batch=229
# 101: loss=1.278, reward_mean=0.010, reward_bound=0.049, batch=230
# 102: loss=1.276, reward_mean=0.020, reward_bound=0.131, batch=231
# 103: loss=1.274, reward_mean=0.030, reward_bound=0.135, batch=227
# 104: loss=1.274, reward_mean=0.010, reward_bound=0.000, batch=228
# 105: loss=1.273, reward_mean=0.040, reward_bound=0.150, batch=223
# 106: loss=1.272, reward_mean=0.010, reward_bound=0.000, batch=224
# 107: loss=1.271, reward_mean=0.030, reward_bound=0.098, batch=227
# 108: loss=1.271, reward_mean=0.020, reward_bound=0.088, batch=229
# 109: loss=1.268, reward_mean=0.050, reward_bound=0.167, batch=217
# 110: loss=1.267, reward_mean=0.060, reward_bound=0.170, batch=222
# 111: loss=1.266, reward_mean=0.000, reward_bound=0.000, batch=222
# 112: loss=1.266, reward_mean=0.020, reward_bound=0.000, batch=224
# 113: loss=1.264, reward_mean=0.030, reward_bound=0.150, batch=227
# 114: loss=1.255, reward_mean=0.040, reward_bound=0.185, batch=218
# 115: loss=1.253, reward_mean=0.040, reward_bound=0.010, batch=222
# 116: loss=1.252, reward_mean=0.020, reward_bound=0.000, batch=224
# 117: loss=1.252, reward_mean=0.020, reward_bound=0.000, batch=226
# 118: loss=1.253, reward_mean=0.030, reward_bound=0.098, batch=227
# 119: loss=1.245, reward_mean=0.100, reward_bound=0.206, batch=218
# 120: loss=1.243, reward_mean=0.030, reward_bound=0.000, batch=221
# 121: loss=1.241, reward_mean=0.050, reward_bound=0.206, batch=224
# 122: loss=1.240, reward_mean=0.020, reward_bound=0.000, batch=226
# 123: loss=1.230, reward_mean=0.040, reward_bound=0.229, batch=210
# 124: loss=1.230, reward_mean=0.030, reward_bound=0.000, batch=213
# 125: loss=1.227, reward_mean=0.040, reward_bound=0.000, batch=217
# 126: loss=1.226, reward_mean=0.020, reward_bound=0.000, batch=219
# 127: loss=1.222, reward_mean=0.030, reward_bound=0.000, batch=222
# 128: loss=1.222, reward_mean=0.020, reward_bound=0.000, batch=224
# 129: loss=1.222, reward_mean=0.030, reward_bound=0.042, batch=227
# 130: loss=1.223, reward_mean=0.030, reward_bound=0.129, batch=229
# 131: loss=1.221, reward_mean=0.030, reward_bound=0.157, batch=230
# 132: loss=1.222, reward_mean=0.040, reward_bound=0.167, batch=230
# 133: loss=1.222, reward_mean=0.040, reward_bound=0.229, batch=230
# 134: loss=1.210, reward_mean=0.100, reward_bound=0.254, batch=216
# 135: loss=1.208, reward_mean=0.070, reward_bound=0.207, batch=221
# 136: loss=1.207, reward_mean=0.050, reward_bound=0.098, batch=224
# 137: loss=1.206, reward_mean=0.060, reward_bound=0.226, batch=227
# 138: loss=1.206, reward_mean=0.050, reward_bound=0.254, batch=225
# 139: loss=1.202, reward_mean=0.040, reward_bound=0.282, batch=191
# 140: loss=1.202, reward_mean=0.040, reward_bound=0.000, batch=195
# 141: loss=1.201, reward_mean=0.040, reward_bound=0.000, batch=199
# 142: loss=1.199, reward_mean=0.070, reward_bound=0.000, batch=206
# 143: loss=1.197, reward_mean=0.040, reward_bound=0.000, batch=210
# 144: loss=1.194, reward_mean=0.050, reward_bound=0.000, batch=215
# 145: loss=1.196, reward_mean=0.080, reward_bound=0.157, batch=220
# 146: loss=1.192, reward_mean=0.060, reward_bound=0.200, batch=224
# 147: loss=1.189, reward_mean=0.070, reward_bound=0.226, batch=227
# 148: loss=1.189, reward_mean=0.050, reward_bound=0.229, batch=225
# 149: loss=1.187, reward_mean=0.050, reward_bound=0.254, batch=225
# 150: loss=1.186, reward_mean=0.030, reward_bound=0.190, batch=227
# 151: loss=1.187, reward_mean=0.050, reward_bound=0.282, batch=224
# 152: loss=1.187, reward_mean=0.030, reward_bound=0.167, batch=227
# 153: loss=1.188, reward_mean=0.050, reward_bound=0.263, batch=229
# 154: loss=1.188, reward_mean=0.040, reward_bound=0.265, batch=230
# 155: loss=1.178, reward_mean=0.050, reward_bound=0.314, batch=201
# 156: loss=1.173, reward_mean=0.040, reward_bound=0.000, batch=205
# 157: loss=1.171, reward_mean=0.050, reward_bound=0.000, batch=210
# 158: loss=1.171, reward_mean=0.000, reward_bound=0.000, batch=210
# 159: loss=1.172, reward_mean=0.040, reward_bound=0.000, batch=214
# 160: loss=1.169, reward_mean=0.060, reward_bound=0.109, batch=220
# 161: loss=1.171, reward_mean=0.090, reward_bound=0.194, batch=224
# 162: loss=1.170, reward_mean=0.090, reward_bound=0.254, batch=224
# 163: loss=1.168, reward_mean=0.040, reward_bound=0.280, batch=227
# 164: loss=1.168, reward_mean=0.050, reward_bound=0.282, batch=227
# 165: loss=1.169, reward_mean=0.050, reward_bound=0.267, batch=229
# 166: loss=1.167, reward_mean=0.070, reward_bound=0.314, batch=229
# 167: loss=1.166, reward_mean=0.020, reward_bound=0.292, batch=230
# 168: loss=1.165, reward_mean=0.020, reward_bound=0.134, batch=231
# 169: loss=1.148, reward_mean=0.080, reward_bound=0.349, batch=181
# 170: loss=1.147, reward_mean=0.070, reward_bound=0.000, batch=188
# 171: loss=1.148, reward_mean=0.060, reward_bound=0.000, batch=194
# 172: loss=1.149, reward_mean=0.040, reward_bound=0.000, batch=198
# 173: loss=1.148, reward_mean=0.090, reward_bound=0.000, batch=207
# 174: loss=1.145, reward_mean=0.090, reward_bound=0.063, batch=215
# 175: loss=1.147, reward_mean=0.050, reward_bound=0.014, batch=220
# 176: loss=1.147, reward_mean=0.040, reward_bound=0.050, batch=224
# 177: loss=1.144, reward_mean=0.040, reward_bound=0.087, batch=227
# 178: loss=1.143, reward_mean=0.040, reward_bound=0.117, batch=229
# 179: loss=1.144, reward_mean=0.080, reward_bound=0.206, batch=228
# 180: loss=1.137, reward_mean=0.100, reward_bound=0.254, batch=225
# 181: loss=1.135, reward_mean=0.050, reward_bound=0.177, batch=227
# 182: loss=1.134, reward_mean=0.060, reward_bound=0.277, batch=229
# 183: loss=1.134, reward_mean=0.080, reward_bound=0.282, batch=222
# 184: loss=1.137, reward_mean=0.030, reward_bound=0.024, batch=225
# 185: loss=1.133, reward_mean=0.070, reward_bound=0.229, batch=226
# 186: loss=1.135, reward_mean=0.080, reward_bound=0.314, batch=225
# 187: loss=1.137, reward_mean=0.050, reward_bound=0.349, batch=218
# 188: loss=1.136, reward_mean=0.050, reward_bound=0.090, batch=222
# 189: loss=1.134, reward_mean=0.030, reward_bound=0.007, batch=225
# 190: loss=1.136, reward_mean=0.030, reward_bound=0.055, batch=227
# 191: loss=1.135, reward_mean=0.060, reward_bound=0.267, batch=229
# 192: loss=1.133, reward_mean=0.070, reward_bound=0.282, batch=229
# 193: loss=1.132, reward_mean=0.050, reward_bound=0.314, batch=227
# 194: loss=1.133, reward_mean=0.070, reward_bound=0.349, batch=226
# 195: loss=1.132, reward_mean=0.030, reward_bound=0.202, batch=228
# 196: loss=1.112, reward_mean=0.090, reward_bound=0.387, batch=153
# 197: loss=1.107, reward_mean=0.060, reward_bound=0.000, batch=159
# 198: loss=1.106, reward_mean=0.030, reward_bound=0.000, batch=162
# 199: loss=1.107, reward_mean=0.100, reward_bound=0.000, batch=172
# 200: loss=1.106, reward_mean=0.080, reward_bound=0.000, batch=180
# 201: loss=1.103, reward_mean=0.050, reward_bound=0.000, batch=185
# 202: loss=1.104, reward_mean=0.060, reward_bound=0.000, batch=191
# 203: loss=1.107, reward_mean=0.080, reward_bound=0.000, batch=199
# 204: loss=1.110, reward_mean=0.070, reward_bound=0.000, batch=206
# 205: loss=1.106, reward_mean=0.050, reward_bound=0.000, batch=211
# 206: loss=1.105, reward_mean=0.090, reward_bound=0.047, batch=217
# 207: loss=1.104, reward_mean=0.050, reward_bound=0.052, batch=222
# 208: loss=1.103, reward_mean=0.060, reward_bound=0.082, batch=225
# 209: loss=1.097, reward_mean=0.050, reward_bound=0.127, batch=227
# 210: loss=1.100, reward_mean=0.030, reward_bound=0.150, batch=226
# 211: loss=1.099, reward_mean=0.020, reward_bound=0.083, batch=228
# 212: loss=1.095, reward_mean=0.060, reward_bound=0.185, batch=228
# 213: loss=1.095, reward_mean=0.050, reward_bound=0.206, batch=226
# 214: loss=1.091, reward_mean=0.030, reward_bound=0.229, batch=221
# 215: loss=1.090, reward_mean=0.050, reward_bound=0.185, batch=224
# 216: loss=1.091, reward_mean=0.040, reward_bound=0.254, batch=218
# 217: loss=1.091, reward_mean=0.040, reward_bound=0.012, batch=222
# 218: loss=1.088, reward_mean=0.060, reward_bound=0.214, batch=225
# 219: loss=1.089, reward_mean=0.070, reward_bound=0.282, batch=220
# 220: loss=1.091, reward_mean=0.050, reward_bound=0.247, batch=224
# 221: loss=1.087, reward_mean=0.030, reward_bound=0.206, batch=227
# 222: loss=1.085, reward_mean=0.100, reward_bound=0.277, batch=229
# 223: loss=1.085, reward_mean=0.050, reward_bound=0.282, batch=229
# 224: loss=1.088, reward_mean=0.040, reward_bound=0.314, batch=219
# 225: loss=1.086, reward_mean=0.060, reward_bound=0.328, batch=223
# 226: loss=1.091, reward_mean=0.110, reward_bound=0.349, batch=204
# 227: loss=1.091, reward_mean=0.050, reward_bound=0.000, batch=209
# 228: loss=1.089, reward_mean=0.020, reward_bound=0.000, batch=211
# 229: loss=1.089, reward_mean=0.040, reward_bound=0.000, batch=215
# 230: loss=1.088, reward_mean=0.040, reward_bound=0.000, batch=219
# 231: loss=1.088, reward_mean=0.040, reward_bound=0.039, batch=223
# 232: loss=1.090, reward_mean=0.030, reward_bound=0.059, batch=226
# 233: loss=1.092, reward_mean=0.050, reward_bound=0.158, batch=228
# 234: loss=1.085, reward_mean=0.080, reward_bound=0.231, batch=229
# 235: loss=1.090, reward_mean=0.050, reward_bound=0.254, batch=228
# 236: loss=1.088, reward_mean=0.030, reward_bound=0.282, batch=228
# 237: loss=1.089, reward_mean=0.030, reward_bound=0.208, batch=229
# 238: loss=1.088, reward_mean=0.060, reward_bound=0.295, batch=230
# 239: loss=1.088, reward_mean=0.040, reward_bound=0.338, batch=231
# 240: loss=1.087, reward_mean=0.060, reward_bound=0.349, batch=228
# 241: loss=1.088, reward_mean=0.060, reward_bound=0.268, batch=229
# 242: loss=1.086, reward_mean=0.070, reward_bound=0.387, batch=201
# 243: loss=1.082, reward_mean=0.050, reward_bound=0.000, batch=206
# 244: loss=1.081, reward_mean=0.030, reward_bound=0.000, batch=209
# 245: loss=1.082, reward_mean=0.060, reward_bound=0.000, batch=215
# 246: loss=1.083, reward_mean=0.050, reward_bound=0.016, batch=220
# 247: loss=1.083, reward_mean=0.110, reward_bound=0.222, batch=224
# 248: loss=1.082, reward_mean=0.040, reward_bound=0.167, batch=225
# 249: loss=1.082, reward_mean=0.010, reward_bound=0.000, batch=226
# 250: loss=1.076, reward_mean=0.130, reward_bound=0.268, batch=228
# 251: loss=1.073, reward_mean=0.040, reward_bound=0.282, batch=227
# 252: loss=1.074, reward_mean=0.070, reward_bound=0.314, batch=227
# 253: loss=1.075, reward_mean=0.040, reward_bound=0.309, batch=229
# 254: loss=1.074, reward_mean=0.040, reward_bound=0.221, batch=230
# 255: loss=1.074, reward_mean=0.070, reward_bound=0.349, batch=230
# 256: loss=1.076, reward_mean=0.070, reward_bound=0.387, batch=226
# 257: loss=1.074, reward_mean=0.040, reward_bound=0.335, batch=228
# 258: loss=1.073, reward_mean=0.050, reward_bound=0.293, batch=229
# 259: loss=1.072, reward_mean=0.130, reward_bound=0.405, batch=230
# 260: loss=1.073, reward_mean=0.040, reward_bound=0.406, batch=231
# 261: loss=1.059, reward_mean=0.080, reward_bound=0.430, batch=137
# 262: loss=1.065, reward_mean=0.070, reward_bound=0.000, batch=144
# 263: loss=1.065, reward_mean=0.050, reward_bound=0.000, batch=149
# 264: loss=1.072, reward_mean=0.070, reward_bound=0.000, batch=156
# 265: loss=1.075, reward_mean=0.060, reward_bound=0.000, batch=162
# 266: loss=1.074, reward_mean=0.040, reward_bound=0.000, batch=166
# 267: loss=1.071, reward_mean=0.050, reward_bound=0.000, batch=171
# 268: loss=1.068, reward_mean=0.070, reward_bound=0.000, batch=178
# 269: loss=1.069, reward_mean=0.030, reward_bound=0.000, batch=181
# 270: loss=1.068, reward_mean=0.070, reward_bound=0.000, batch=188
# 271: loss=1.066, reward_mean=0.050, reward_bound=0.000, batch=193
# 272: loss=1.067, reward_mean=0.070, reward_bound=0.000, batch=200
# 273: loss=1.068, reward_mean=0.050, reward_bound=0.000, batch=205
# 274: loss=1.068, reward_mean=0.010, reward_bound=0.000, batch=206
# 275: loss=1.069, reward_mean=0.010, reward_bound=0.000, batch=207
# 276: loss=1.069, reward_mean=0.030, reward_bound=0.000, batch=210
# 277: loss=1.066, reward_mean=0.070, reward_bound=0.030, batch=217
# 278: loss=1.052, reward_mean=0.110, reward_bound=0.098, batch=221
# 279: loss=1.050, reward_mean=0.050, reward_bound=0.135, batch=220
# 280: loss=1.050, reward_mean=0.010, reward_bound=0.000, batch=221
# 281: loss=1.046, reward_mean=0.040, reward_bound=0.167, batch=224
# 282: loss=1.048, reward_mean=0.050, reward_bound=0.180, batch=227
# 283: loss=1.050, reward_mean=0.050, reward_bound=0.185, batch=223
# 284: loss=1.044, reward_mean=0.100, reward_bound=0.206, batch=224
# 285: loss=1.049, reward_mean=0.090, reward_bound=0.229, batch=226
# 286: loss=1.047, reward_mean=0.090, reward_bound=0.254, batch=225
# 287: loss=1.048, reward_mean=0.060, reward_bound=0.260, batch=227
# 288: loss=1.049, reward_mean=0.110, reward_bound=0.282, batch=217
# 289: loss=1.048, reward_mean=0.040, reward_bound=0.000, batch=221
# 290: loss=1.047, reward_mean=0.060, reward_bound=0.167, batch=224
# 291: loss=1.049, reward_mean=0.080, reward_bound=0.249, batch=227
# 292: loss=1.054, reward_mean=0.070, reward_bound=0.314, batch=215
# 293: loss=1.053, reward_mean=0.050, reward_bound=0.056, batch=220
# 294: loss=1.053, reward_mean=0.070, reward_bound=0.266, batch=224
# 295: loss=1.054, reward_mean=0.030, reward_bound=0.206, batch=227
# 296: loss=1.051, reward_mean=0.060, reward_bound=0.229, batch=228
# 297: loss=1.050, reward_mean=0.060, reward_bound=0.286, batch=229
# 298: loss=1.049, reward_mean=0.060, reward_bound=0.263, batch=230
# 299: loss=1.045, reward_mean=0.080, reward_bound=0.338, batch=231
# 300: loss=1.046, reward_mean=0.030, reward_bound=0.349, batch=209
# 301: loss=1.046, reward_mean=0.050, reward_bound=0.000, batch=214
# 302: loss=1.048, reward_mean=0.060, reward_bound=0.058, batch=220
# 303: loss=1.047, reward_mean=0.030, reward_bound=0.000, batch=223
# 304: loss=1.048, reward_mean=0.040, reward_bound=0.099, batch=226
# 305: loss=1.049, reward_mean=0.050, reward_bound=0.196, batch=228
# 306: loss=1.048, reward_mean=0.040, reward_bound=0.208, batch=229
# 307: loss=1.044, reward_mean=0.100, reward_bound=0.265, batch=230
# 308: loss=1.045, reward_mean=0.070, reward_bound=0.304, batch=231
# 309: loss=1.046, reward_mean=0.020, reward_bound=0.314, batch=229
# 310: loss=1.046, reward_mean=0.070, reward_bound=0.349, batch=226
# 311: loss=1.046, reward_mean=0.040, reward_bound=0.335, batch=228
# 312: loss=1.045, reward_mean=0.040, reward_bound=0.387, batch=201
# 313: loss=1.042, reward_mean=0.040, reward_bound=0.000, batch=205
# 314: loss=1.039, reward_mean=0.050, reward_bound=0.000, batch=210
# 315: loss=1.039, reward_mean=0.050, reward_bound=0.000, batch=215
# 316: loss=1.044, reward_mean=0.050, reward_bound=0.014, batch=220
# 317: loss=1.042, reward_mean=0.030, reward_bound=0.000, batch=223
# 318: loss=1.044, reward_mean=0.040, reward_bound=0.102, batch=226
# 319: loss=1.043, reward_mean=0.040, reward_bound=0.128, batch=228
# 320: loss=1.041, reward_mean=0.070, reward_bound=0.229, batch=228
# 321: loss=1.040, reward_mean=0.070, reward_bound=0.257, batch=229
# 322: loss=1.046, reward_mean=0.040, reward_bound=0.282, batch=228
# 323: loss=1.041, reward_mean=0.130, reward_bound=0.349, batch=225
# 324: loss=1.039, reward_mean=0.070, reward_bound=0.356, batch=227
# 325: loss=1.042, reward_mean=0.050, reward_bound=0.198, batch=229
# 326: loss=1.039, reward_mean=0.050, reward_bound=0.314, batch=229
# 327: loss=1.037, reward_mean=0.050, reward_bound=0.387, batch=221
# 328: loss=1.034, reward_mean=0.070, reward_bound=0.430, batch=189
# 329: loss=1.034, reward_mean=0.060, reward_bound=0.000, batch=195
# 330: loss=1.034, reward_mean=0.000, reward_bound=0.000, batch=195
# 331: loss=1.033, reward_mean=0.070, reward_bound=0.000, batch=202
# 332: loss=1.032, reward_mean=0.040, reward_bound=0.000, batch=206
# 333: loss=1.031, reward_mean=0.040, reward_bound=0.000, batch=210
# 334: loss=1.028, reward_mean=0.020, reward_bound=0.000, batch=212
# 335: loss=1.029, reward_mean=0.040, reward_bound=0.000, batch=216
# 336: loss=1.023, reward_mean=0.040, reward_bound=0.000, batch=220
# 337: loss=1.024, reward_mean=0.050, reward_bound=0.118, batch=224
# 338: loss=1.032, reward_mean=0.070, reward_bound=0.150, batch=226
# 339: loss=1.029, reward_mean=0.040, reward_bound=0.167, batch=227
# 340: loss=1.029, reward_mean=0.120, reward_bound=0.206, batch=228
# 341: loss=1.027, reward_mean=0.030, reward_bound=0.229, batch=228
# 342: loss=1.028, reward_mean=0.080, reward_bound=0.254, batch=227
# 343: loss=1.035, reward_mean=0.060, reward_bound=0.282, batch=224
# 344: loss=1.031, reward_mean=0.070, reward_bound=0.314, batch=223
# 345: loss=1.031, reward_mean=0.010, reward_bound=0.000, batch=224
# 346: loss=1.028, reward_mean=0.090, reward_bound=0.349, batch=221
# 347: loss=1.028, reward_mean=0.060, reward_bound=0.314, batch=223
# 348: loss=1.026, reward_mean=0.050, reward_bound=0.206, batch=225
# 349: loss=1.025, reward_mean=0.020, reward_bound=0.051, batch=227
# 350: loss=1.023, reward_mean=0.060, reward_bound=0.282, batch=228
# 351: loss=1.024, reward_mean=0.080, reward_bound=0.349, batch=228
# 352: loss=1.024, reward_mean=0.060, reward_bound=0.387, batch=214
# 353: loss=1.027, reward_mean=0.060, reward_bound=0.167, batch=220
# 354: loss=1.029, reward_mean=0.050, reward_bound=0.125, batch=224
# 355: loss=1.028, reward_mean=0.040, reward_bound=0.183, batch=227
# 356: loss=1.021, reward_mean=0.070, reward_bound=0.282, batch=228
# 357: loss=1.020, reward_mean=0.020, reward_bound=0.187, batch=229
# 358: loss=1.023, reward_mean=0.070, reward_bound=0.314, batch=227
# 359: loss=1.023, reward_mean=0.060, reward_bound=0.282, batch=228
# 360: loss=1.023, reward_mean=0.060, reward_bound=0.387, batch=224
# 361: loss=1.024, reward_mean=0.030, reward_bound=0.229, batch=227
# 362: loss=1.021, reward_mean=0.080, reward_bound=0.387, batch=228
# 363: loss=1.024, reward_mean=0.040, reward_bound=0.430, batch=207
# 364: loss=1.027, reward_mean=0.050, reward_bound=0.000, batch=212
# 365: loss=1.024, reward_mean=0.040, reward_bound=0.000, batch=216
# 366: loss=1.025, reward_mean=0.030, reward_bound=0.000, batch=219
# 367: loss=1.024, reward_mean=0.040, reward_bound=0.054, batch=223
# 368: loss=1.021, reward_mean=0.050, reward_bound=0.190, batch=226
# 369: loss=1.017, reward_mean=0.080, reward_bound=0.229, batch=227
# 370: loss=1.019, reward_mean=0.040, reward_bound=0.254, batch=226
# 371: loss=1.021, reward_mean=0.090, reward_bound=0.314, batch=225
# 372: loss=1.024, reward_mean=0.060, reward_bound=0.349, batch=219
# 373: loss=1.027, reward_mean=0.050, reward_bound=0.213, batch=223
# 374: loss=1.024, reward_mean=0.100, reward_bound=0.387, batch=221
# 375: loss=1.022, reward_mean=0.040, reward_bound=0.254, batch=224
# 376: loss=1.021, reward_mean=0.050, reward_bound=0.280, batch=227
# 377: loss=1.021, reward_mean=0.090, reward_bound=0.380, batch=229
# 378: loss=1.022, reward_mean=0.060, reward_bound=0.387, batch=227
# 379: loss=1.022, reward_mean=0.040, reward_bound=0.342, batch=229
# 380: loss=1.025, reward_mean=0.060, reward_bound=0.364, batch=230
# 381: loss=1.024, reward_mean=0.050, reward_bound=0.365, batch=231
# 382: loss=1.025, reward_mean=0.120, reward_bound=0.387, batch=230
# 383: loss=1.025, reward_mean=0.080, reward_bound=0.430, batch=221
# 384: loss=1.025, reward_mean=0.070, reward_bound=0.282, batch=223
# 385: loss=1.024, reward_mean=0.060, reward_bound=0.290, batch=226
# 386: loss=1.026, reward_mean=0.070, reward_bound=0.331, batch=228
# 387: loss=1.023, reward_mean=0.090, reward_bound=0.349, batch=227
# 388: loss=1.025, reward_mean=0.050, reward_bound=0.206, batch=228
# 389: loss=1.025, reward_mean=0.060, reward_bound=0.387, batch=228
# 390: loss=1.025, reward_mean=0.060, reward_bound=0.430, batch=225
# 391: loss=1.030, reward_mean=0.040, reward_bound=0.175, batch=227
# 392: loss=1.024, reward_mean=0.070, reward_bound=0.297, batch=229
# 393: loss=1.026, reward_mean=0.040, reward_bound=0.278, batch=230
# 394: loss=1.028, reward_mean=0.080, reward_bound=0.338, batch=231
# 395: loss=1.028, reward_mean=0.080, reward_bound=0.430, batch=230
# 396: loss=1.027, reward_mean=0.040, reward_bound=0.418, batch=231
# 397: loss=1.027, reward_mean=0.050, reward_bound=0.430, batch=230
# 398: loss=1.028, reward_mean=0.100, reward_bound=0.338, batch=231
# 399: loss=1.028, reward_mean=0.070, reward_bound=0.387, batch=231
# 400: loss=1.027, reward_mean=0.090, reward_bound=0.430, batch=231
# 401: loss=1.011, reward_mean=0.040, reward_bound=0.478, batch=102
# 402: loss=1.019, reward_mean=0.080, reward_bound=0.000, batch=110
# 403: loss=1.021, reward_mean=0.050, reward_bound=0.000, batch=115
# 404: loss=1.012, reward_mean=0.100, reward_bound=0.000, batch=125
# 405: loss=1.013, reward_mean=0.040, reward_bound=0.000, batch=129
# 406: loss=1.013, reward_mean=0.060, reward_bound=0.000, batch=135
# 407: loss=1.013, reward_mean=0.050, reward_bound=0.000, batch=140
# 408: loss=1.012, reward_mean=0.050, reward_bound=0.000, batch=145
# 409: loss=1.016, reward_mean=0.070, reward_bound=0.000, batch=152
# 410: loss=1.011, reward_mean=0.080, reward_bound=0.000, batch=160
# 411: loss=1.011, reward_mean=0.100, reward_bound=0.000, batch=170
# 412: loss=1.015, reward_mean=0.090, reward_bound=0.000, batch=179
# 413: loss=1.010, reward_mean=0.070, reward_bound=0.000, batch=186
# 414: loss=1.009, reward_mean=0.100, reward_bound=0.000, batch=196
# 415: loss=1.007, reward_mean=0.070, reward_bound=0.000, batch=203
# 416: loss=1.005, reward_mean=0.040, reward_bound=0.000, batch=207
# 417: loss=1.009, reward_mean=0.060, reward_bound=0.000, batch=213
# 418: loss=1.008, reward_mean=0.050, reward_bound=0.000, batch=218
# 419: loss=1.005, reward_mean=0.060, reward_bound=0.080, batch=221
# 420: loss=1.008, reward_mean=0.090, reward_bound=0.109, batch=223
# 421: loss=1.004, reward_mean=0.090, reward_bound=0.144, batch=226
# 422: loss=1.002, reward_mean=0.090, reward_bound=0.167, batch=226
# 423: loss=1.002, reward_mean=0.090, reward_bound=0.185, batch=222
# 424: loss=0.999, reward_mean=0.070, reward_bound=0.206, batch=227
# 425: loss=0.999, reward_mean=0.050, reward_bound=0.202, batch=229
# 426: loss=1.004, reward_mean=0.060, reward_bound=0.206, batch=228
# 427: loss=0.998, reward_mean=0.080, reward_bound=0.229, batch=218
# 428: loss=0.997, reward_mean=0.050, reward_bound=0.161, batch=222
# 429: loss=0.998, reward_mean=0.050, reward_bound=0.185, batch=225
# 430: loss=1.000, reward_mean=0.070, reward_bound=0.254, batch=210
# 431: loss=1.002, reward_mean=0.040, reward_bound=0.000, batch=214
# 432: loss=0.998, reward_mean=0.050, reward_bound=0.000, batch=219
# 433: loss=1.003, reward_mean=0.090, reward_bound=0.265, batch=223
# 434: loss=1.004, reward_mean=0.020, reward_bound=0.000, batch=225
# 435: loss=1.002, reward_mean=0.040, reward_bound=0.282, batch=209
# 436: loss=0.998, reward_mean=0.050, reward_bound=0.000, batch=214
# 437: loss=0.998, reward_mean=0.080, reward_bound=0.135, batch=219
# 438: loss=1.003, reward_mean=0.060, reward_bound=0.103, batch=223
# 439: loss=1.001, reward_mean=0.070, reward_bound=0.261, batch=226
# 440: loss=1.003, reward_mean=0.070, reward_bound=0.268, batch=228
# 441: loss=0.998, reward_mean=0.060, reward_bound=0.314, batch=203
# 442: loss=1.005, reward_mean=0.060, reward_bound=0.000, batch=209
# 443: loss=1.003, reward_mean=0.080, reward_bound=0.113, batch=216
# 444: loss=1.001, reward_mean=0.050, reward_bound=0.068, batch=221
# 445: loss=0.995, reward_mean=0.050, reward_bound=0.135, batch=223
# 446: loss=0.994, reward_mean=0.080, reward_bound=0.198, batch=226
# 447: loss=0.995, reward_mean=0.070, reward_bound=0.241, batch=228
# 448: loss=0.997, reward_mean=0.030, reward_bound=0.254, batch=228
# 449: loss=0.995, reward_mean=0.070, reward_bound=0.282, batch=226
# 450: loss=0.991, reward_mean=0.080, reward_bound=0.331, batch=228
# 451: loss=0.990, reward_mean=0.040, reward_bound=0.264, batch=229
# 452: loss=0.984, reward_mean=0.090, reward_bound=0.349, batch=205
# 453: loss=0.984, reward_mean=0.030, reward_bound=0.000, batch=208
# 454: loss=0.987, reward_mean=0.070, reward_bound=0.001, batch=215
# 455: loss=0.985, reward_mean=0.090, reward_bound=0.098, batch=219
# 456: loss=0.980, reward_mean=0.050, reward_bound=0.182, batch=223
# 457: loss=0.983, reward_mean=0.080, reward_bound=0.254, batch=224
# 458: loss=0.985, reward_mean=0.120, reward_bound=0.311, batch=227
# 459: loss=0.985, reward_mean=0.060, reward_bound=0.150, batch=228
# 460: loss=0.983, reward_mean=0.060, reward_bound=0.317, batch=229
# 461: loss=0.984, reward_mean=0.060, reward_bound=0.349, batch=228
# 462: loss=0.984, reward_mean=0.050, reward_bound=0.387, batch=183
# 463: loss=0.987, reward_mean=0.050, reward_bound=0.000, batch=188
# 464: loss=0.986, reward_mean=0.030, reward_bound=0.000, batch=191
# 465: loss=0.977, reward_mean=0.100, reward_bound=0.000, batch=201
# 466: loss=0.981, reward_mean=0.060, reward_bound=0.000, batch=207
# 467: loss=0.978, reward_mean=0.080, reward_bound=0.042, batch=215
# 468: loss=0.978, reward_mean=0.040, reward_bound=0.000, batch=219
# 469: loss=0.979, reward_mean=0.040, reward_bound=0.021, batch=223
# 470: loss=0.976, reward_mean=0.040, reward_bound=0.056, batch=226
# 471: loss=0.975, reward_mean=0.060, reward_bound=0.084, batch=228
# 472: loss=0.971, reward_mean=0.060, reward_bound=0.140, batch=229
# 473: loss=0.972, reward_mean=0.080, reward_bound=0.229, batch=229
# 474: loss=0.973, reward_mean=0.050, reward_bound=0.254, batch=226
# 475: loss=0.972, reward_mean=0.060, reward_bound=0.314, batch=215
# 476: loss=0.972, reward_mean=0.010, reward_bound=0.000, batch=216
# 477: loss=0.971, reward_mean=0.040, reward_bound=0.000, batch=220
# 478: loss=0.972, reward_mean=0.030, reward_bound=0.000, batch=223
# 479: loss=0.973, reward_mean=0.040, reward_bound=0.071, batch=226
# 480: loss=0.971, reward_mean=0.030, reward_bound=0.095, batch=228
# 481: loss=0.975, reward_mean=0.040, reward_bound=0.150, batch=228
# 482: loss=0.976, reward_mean=0.130, reward_bound=0.349, batch=217
# 483: loss=0.972, reward_mean=0.080, reward_bound=0.302, batch=222
# 484: loss=0.971, reward_mean=0.060, reward_bound=0.272, batch=225
# 485: loss=0.972, reward_mean=0.060, reward_bound=0.314, batch=225
# 486: loss=0.971, reward_mean=0.050, reward_bound=0.321, batch=227
# 487: loss=0.968, reward_mean=0.060, reward_bound=0.349, batch=225
# 488: loss=0.972, reward_mean=0.080, reward_bound=0.387, batch=222
# 489: loss=0.974, reward_mean=0.100, reward_bound=0.360, batch=225
# 490: loss=0.961, reward_mean=0.100, reward_bound=0.430, batch=188
# 491: loss=0.955, reward_mean=0.070, reward_bound=0.000, batch=195
# 492: loss=0.953, reward_mean=0.060, reward_bound=0.000, batch=201
# 493: loss=0.959, reward_mean=0.130, reward_bound=0.135, batch=209
# 494: loss=0.960, reward_mean=0.050, reward_bound=0.000, batch=214
# 495: loss=0.957, reward_mean=0.070, reward_bound=0.093, batch=220
# 496: loss=0.961, reward_mean=0.050, reward_bound=0.106, batch=224
# 497: loss=0.959, reward_mean=0.120, reward_bound=0.226, batch=227
# 498: loss=0.957, reward_mean=0.050, reward_bound=0.229, batch=228
# 499: loss=0.950, reward_mean=0.030, reward_bound=0.254, batch=225
# 500: loss=0.952, reward_mean=0.080, reward_bound=0.314, batch=224
# 501: loss=0.951, reward_mean=0.080, reward_bound=0.339, batch=227
# 502: loss=0.952, reward_mean=0.040, reward_bound=0.282, batch=228
# 503: loss=0.953, reward_mean=0.040, reward_bound=0.349, batch=221
# 504: loss=0.950, reward_mean=0.060, reward_bound=0.135, batch=224
# 505: loss=0.948, reward_mean=0.090, reward_bound=0.252, batch=227
# 506: loss=0.947, reward_mean=0.060, reward_bound=0.282, batch=228
# 507: loss=0.946, reward_mean=0.060, reward_bound=0.314, batch=228
# 508: loss=0.950, reward_mean=0.050, reward_bound=0.353, batch=229
# 509: loss=0.951, reward_mean=0.060, reward_bound=0.387, batch=213
# 510: loss=0.957, reward_mean=0.080, reward_bound=0.160, batch=219
# 511: loss=0.953, reward_mean=0.040, reward_bound=0.067, batch=223
# 512: loss=0.949, reward_mean=0.110, reward_bound=0.282, batch=225
# 513: loss=0.950, reward_mean=0.060, reward_bound=0.314, batch=226
# 514: loss=0.945, reward_mean=0.110, reward_bound=0.349, batch=227
# 515: loss=0.945, reward_mean=0.080, reward_bound=0.387, batch=224
# 516: loss=0.942, reward_mean=0.040, reward_bound=0.241, batch=227
# 517: loss=0.942, reward_mean=0.040, reward_bound=0.160, batch=229
# 518: loss=0.941, reward_mean=0.030, reward_bound=0.265, batch=230
# 519: loss=0.942, reward_mean=0.020, reward_bound=0.189, batch=231
# 520: loss=0.947, reward_mean=0.060, reward_bound=0.314, batch=228
# 521: loss=0.946, reward_mean=0.040, reward_bound=0.321, batch=229
# 522: loss=0.945, reward_mean=0.060, reward_bound=0.343, batch=230
# 523: loss=0.944, reward_mean=0.100, reward_bound=0.387, batch=229
# 524: loss=0.944, reward_mean=0.060, reward_bound=0.387, batch=229
# 525: loss=0.944, reward_mean=0.080, reward_bound=0.295, batch=230
# 526: loss=0.946, reward_mean=0.080, reward_bound=0.338, batch=231
# 527: loss=0.950, reward_mean=0.120, reward_bound=0.430, batch=220
# 528: loss=0.949, reward_mean=0.030, reward_bound=0.000, batch=223
# 529: loss=0.949, reward_mean=0.070, reward_bound=0.290, batch=226
# 530: loss=0.949, reward_mean=0.060, reward_bound=0.256, batch=228
# 531: loss=0.947, reward_mean=0.050, reward_bound=0.286, batch=229
# 532: loss=0.946, reward_mean=0.110, reward_bound=0.328, batch=230
# 533: loss=0.945, reward_mean=0.040, reward_bound=0.338, batch=231
# 534: loss=0.946, reward_mean=0.070, reward_bound=0.387, batch=231
# 535: loss=0.946, reward_mean=0.100, reward_bound=0.430, batch=227
# 536: loss=0.945, reward_mean=0.080, reward_bound=0.414, batch=229
# 537: loss=0.948, reward_mean=0.020, reward_bound=0.381, batch=230
# 538: loss=0.944, reward_mean=0.080, reward_bound=0.430, batch=230
# 539: loss=0.943, reward_mean=0.060, reward_bound=0.451, batch=231
# 540: loss=0.943, reward_mean=0.060, reward_bound=0.430, batch=231
# 541: loss=0.958, reward_mean=0.060, reward_bound=0.478, batch=166
# 542: loss=0.958, reward_mean=0.070, reward_bound=0.000, batch=173
# 543: loss=0.953, reward_mean=0.100, reward_bound=0.000, batch=183
# 544: loss=0.950, reward_mean=0.070, reward_bound=0.000, batch=190
# 545: loss=0.947, reward_mean=0.060, reward_bound=0.000, batch=196
# 546: loss=0.944, reward_mean=0.030, reward_bound=0.000, batch=199
# 547: loss=0.944, reward_mean=0.040, reward_bound=0.000, batch=203
# 548: loss=0.943, reward_mean=0.110, reward_bound=0.060, batch=212
# 549: loss=0.946, reward_mean=0.050, reward_bound=0.000, batch=217
# 550: loss=0.944, reward_mean=0.040, reward_bound=0.000, batch=221
# 551: loss=0.945, reward_mean=0.020, reward_bound=0.000, batch=223
# 552: loss=0.953, reward_mean=0.060, reward_bound=0.098, batch=226
# 553: loss=0.952, reward_mean=0.090, reward_bound=0.150, batch=226
# 554: loss=0.953, reward_mean=0.050, reward_bound=0.176, batch=228
# 555: loss=0.942, reward_mean=0.100, reward_bound=0.229, batch=226
# 556: loss=0.943, reward_mean=0.030, reward_bound=0.230, batch=228
# 557: loss=0.944, reward_mean=0.040, reward_bound=0.135, batch=229
# 558: loss=0.950, reward_mean=0.120, reward_bound=0.254, batch=228
# 559: loss=0.951, reward_mean=0.090, reward_bound=0.282, batch=224
# 560: loss=0.951, reward_mean=0.080, reward_bound=0.311, batch=227
# 561: loss=0.943, reward_mean=0.050, reward_bound=0.314, batch=215
# 562: loss=0.945, reward_mean=0.060, reward_bound=0.130, batch=220
# 563: loss=0.944, reward_mean=0.100, reward_bound=0.254, batch=223
# 564: loss=0.945, reward_mean=0.100, reward_bound=0.349, batch=212
# 565: loss=0.942, reward_mean=0.070, reward_bound=0.124, batch=218
# 566: loss=0.940, reward_mean=0.070, reward_bound=0.208, batch=222
# 567: loss=0.940, reward_mean=0.050, reward_bound=0.229, batch=224
# 568: loss=0.941, reward_mean=0.090, reward_bound=0.282, batch=226
# 569: loss=0.942, reward_mean=0.060, reward_bound=0.314, batch=227
# 570: loss=0.940, reward_mean=0.040, reward_bound=0.349, batch=228
# 571: loss=0.939, reward_mean=0.060, reward_bound=0.293, batch=229
# 572: loss=0.940, reward_mean=0.080, reward_bound=0.387, batch=210
# 573: loss=0.939, reward_mean=0.070, reward_bound=0.105, batch=217
# 574: loss=0.936, reward_mean=0.040, reward_bound=0.000, batch=221
# 575: loss=0.934, reward_mean=0.100, reward_bound=0.167, batch=224
# 576: loss=0.941, reward_mean=0.120, reward_bound=0.282, batch=225
# 577: loss=0.942, reward_mean=0.080, reward_bound=0.314, batch=224
# 578: loss=0.940, reward_mean=0.060, reward_bound=0.329, batch=227
# 579: loss=0.941, reward_mean=0.060, reward_bound=0.349, batch=227
# 580: loss=0.937, reward_mean=0.020, reward_bound=0.071, batch=229
# 581: loss=0.938, reward_mean=0.080, reward_bound=0.364, batch=230
# 582: loss=0.938, reward_mean=0.050, reward_bound=0.349, batch=230
# 583: loss=0.935, reward_mean=0.030, reward_bound=0.387, batch=228
# 584: loss=0.939, reward_mean=0.080, reward_bound=0.430, batch=208
# 585: loss=0.938, reward_mean=0.060, reward_bound=0.000, batch=214
# 586: loss=0.935, reward_mean=0.060, reward_bound=0.135, batch=220
# 587: loss=0.933, reward_mean=0.120, reward_bound=0.229, batch=223
# 588: loss=0.933, reward_mean=0.050, reward_bound=0.213, batch=226
# 589: loss=0.931, reward_mean=0.080, reward_bound=0.282, batch=226
# 590: loss=0.936, reward_mean=0.080, reward_bound=0.314, batch=227
# 591: loss=0.936, reward_mean=0.050, reward_bound=0.330, batch=229
# 592: loss=0.934, reward_mean=0.050, reward_bound=0.349, batch=225
# 593: loss=0.933, reward_mean=0.110, reward_bound=0.329, batch=227
# 594: loss=0.933, reward_mean=0.030, reward_bound=0.250, batch=229
# 595: loss=0.934, reward_mean=0.090, reward_bound=0.387, batch=223
# 596: loss=0.936, reward_mean=0.060, reward_bound=0.345, batch=226
# 597: loss=0.936, reward_mean=0.050, reward_bound=0.335, batch=228
# 598: loss=0.938, reward_mean=0.030, reward_bound=0.268, batch=229
# 599: loss=0.938, reward_mean=0.070, reward_bound=0.364, batch=230
# 600: loss=0.933, reward_mean=0.080, reward_bound=0.387, batch=229
# 601: loss=0.935, reward_mean=0.090, reward_bound=0.430, batch=226
# 602: loss=0.936, reward_mean=0.050, reward_bound=0.282, batch=227
# 603: loss=0.936, reward_mean=0.050, reward_bound=0.316, batch=229
# 604: loss=0.934, reward_mean=0.050, reward_bound=0.364, batch=230
# 605: loss=0.934, reward_mean=0.130, reward_bound=0.418, batch=231
# 606: loss=0.932, reward_mean=0.080, reward_bound=0.430, batch=229
# 607: loss=0.932, reward_mean=0.070, reward_bound=0.430, batch=229
# 608: loss=0.930, reward_mean=0.080, reward_bound=0.295, batch=230
# 609: loss=0.932, reward_mean=0.040, reward_bound=0.338, batch=231
# 610: loss=0.932, reward_mean=0.090, reward_bound=0.387, batch=230
# 611: loss=0.931, reward_mean=0.050, reward_bound=0.464, batch=231
# 612: loss=0.943, reward_mean=0.070, reward_bound=0.478, batch=194
# 613: loss=0.943, reward_mean=0.080, reward_bound=0.000, batch=202
# 614: loss=0.941, reward_mean=0.070, reward_bound=0.000, batch=209
# 615: loss=0.942, reward_mean=0.080, reward_bound=0.037, batch=216
# 616: loss=0.944, reward_mean=0.040, reward_bound=0.000, batch=220
# 617: loss=0.942, reward_mean=0.090, reward_bound=0.189, batch=224
# 618: loss=0.933, reward_mean=0.150, reward_bound=0.252, batch=227
# 619: loss=0.932, reward_mean=0.030, reward_bound=0.249, batch=229
# 620: loss=0.934, reward_mean=0.030, reward_bound=0.254, batch=228
# 621: loss=0.937, reward_mean=0.080, reward_bound=0.282, batch=226
# 622: loss=0.936, reward_mean=0.070, reward_bound=0.298, batch=228
# 623: loss=0.939, reward_mean=0.060, reward_bound=0.314, batch=221
# 624: loss=0.937, reward_mean=0.060, reward_bound=0.229, batch=224
# 625: loss=0.938, reward_mean=0.060, reward_bound=0.314, batch=226
# 626: loss=0.937, reward_mean=0.080, reward_bound=0.331, batch=228
# 627: loss=0.941, reward_mean=0.140, reward_bound=0.387, batch=221
# 628: loss=0.940, reward_mean=0.080, reward_bound=0.314, batch=224
# 629: loss=0.942, reward_mean=0.070, reward_bound=0.349, batch=226
# 630: loss=0.942, reward_mean=0.080, reward_bound=0.368, batch=228
# 631: loss=0.941, reward_mean=0.040, reward_bound=0.237, batch=229
# 632: loss=0.942, reward_mean=0.040, reward_bound=0.314, batch=229
# 633: loss=0.942, reward_mean=0.070, reward_bound=0.364, batch=230
# 634: loss=0.939, reward_mean=0.080, reward_bound=0.387, batch=229
# 635: loss=0.939, reward_mean=0.060, reward_bound=0.225, batch=230
# 636: loss=0.937, reward_mean=0.060, reward_bound=0.338, batch=231
# 637: loss=0.939, reward_mean=0.080, reward_bound=0.387, batch=231
# 638: loss=0.939, reward_mean=0.060, reward_bound=0.387, batch=231
# 639: loss=0.936, reward_mean=0.100, reward_bound=0.430, batch=215
# 640: loss=0.937, reward_mean=0.060, reward_bound=0.216, batch=220
# 641: loss=0.935, reward_mean=0.090, reward_bound=0.282, batch=223
# 642: loss=0.935, reward_mean=0.080, reward_bound=0.178, batch=226
# 643: loss=0.936, reward_mean=0.050, reward_bound=0.314, batch=223
# 644: loss=0.933, reward_mean=0.110, reward_bound=0.372, batch=226
# 645: loss=0.934, reward_mean=0.080, reward_bound=0.351, batch=228
# 646: loss=0.935, reward_mean=0.090, reward_bound=0.430, batch=221
# 647: loss=0.934, reward_mean=0.070, reward_bound=0.282, batch=224
# 648: loss=0.934, reward_mean=0.040, reward_bound=0.266, batch=227
# 649: loss=0.936, reward_mean=0.070, reward_bound=0.342, batch=229
# 650: loss=0.939, reward_mean=0.060, reward_bound=0.387, batch=227
# 651: loss=0.937, reward_mean=0.100, reward_bound=0.422, batch=229
# 652: loss=0.936, reward_mean=0.090, reward_bound=0.430, batch=225
# 653: loss=0.934, reward_mean=0.060, reward_bound=0.314, batch=226
# 654: loss=0.935, reward_mean=0.080, reward_bound=0.349, batch=226
# 655: loss=0.934, reward_mean=0.020, reward_bound=0.093, batch=228
# 656: loss=0.938, reward_mean=0.060, reward_bound=0.317, batch=229
# 657: loss=0.937, reward_mean=0.060, reward_bound=0.349, batch=228
# 658: loss=0.938, reward_mean=0.130, reward_bound=0.430, batch=227
# 659: loss=0.939, reward_mean=0.080, reward_bound=0.478, batch=204
# 660: loss=0.932, reward_mean=0.080, reward_bound=0.000, batch=212
# 661: loss=0.932, reward_mean=0.080, reward_bound=0.167, batch=218
# 662: loss=0.935, reward_mean=0.050, reward_bound=0.105, batch=222
# 663: loss=0.932, reward_mean=0.080, reward_bound=0.206, batch=228
# 664: loss=0.934, reward_mean=0.070, reward_bound=0.208, batch=229
# 665: loss=0.940, reward_mean=0.050, reward_bound=0.229, batch=229
# 666: loss=0.943, reward_mean=0.050, reward_bound=0.282, batch=226
# 667: loss=0.937, reward_mean=0.100, reward_bound=0.314, batch=227
# 668: loss=0.939, reward_mean=0.050, reward_bound=0.254, batch=228
# 669: loss=0.940, reward_mean=0.090, reward_bound=0.349, batch=225
# 670: loss=0.938, reward_mean=0.070, reward_bound=0.303, batch=227
# 671: loss=0.938, reward_mean=0.090, reward_bound=0.342, batch=229
# 672: loss=0.941, reward_mean=0.030, reward_bound=0.309, batch=230
# 673: loss=0.942, reward_mean=0.080, reward_bound=0.349, batch=230
# 674: loss=0.944, reward_mean=0.060, reward_bound=0.376, batch=231
# 675: loss=0.940, reward_mean=0.050, reward_bound=0.387, batch=228
# 676: loss=0.930, reward_mean=0.070, reward_bound=0.430, batch=219
# 677: loss=0.928, reward_mean=0.080, reward_bound=0.328, batch=223
# 678: loss=0.928, reward_mean=0.000, reward_bound=0.000, batch=223
# 679: loss=0.927, reward_mean=0.060, reward_bound=0.184, batch=226
# 680: loss=0.929, reward_mean=0.120, reward_bound=0.368, batch=228
# 681: loss=0.928, reward_mean=0.050, reward_bound=0.387, batch=224
# 682: loss=0.927, reward_mean=0.050, reward_bound=0.275, batch=227
# 683: loss=0.926, reward_mean=0.050, reward_bound=0.335, batch=229
# 684: loss=0.927, reward_mean=0.060, reward_bound=0.349, batch=229
# 685: loss=0.927, reward_mean=0.080, reward_bound=0.405, batch=230
# 686: loss=0.930, reward_mean=0.070, reward_bound=0.338, batch=231
# 687: loss=0.926, reward_mean=0.080, reward_bound=0.430, batch=227
# 688: loss=0.927, reward_mean=0.040, reward_bound=0.445, batch=229
# 689: loss=0.926, reward_mean=0.040, reward_bound=0.364, batch=230
# 690: loss=0.925, reward_mean=0.040, reward_bound=0.376, batch=231
# 691: loss=0.925, reward_mean=0.050, reward_bound=0.430, batch=231
# 692: loss=0.925, reward_mean=0.070, reward_bound=0.387, batch=231
# 693: loss=0.933, reward_mean=0.060, reward_bound=0.478, batch=214
# 694: loss=0.933, reward_mean=0.050, reward_bound=0.000, batch=219
# 695: loss=0.931, reward_mean=0.100, reward_bound=0.229, batch=222
# 696: loss=0.928, reward_mean=0.080, reward_bound=0.292, batch=225
# 697: loss=0.929, reward_mean=0.020, reward_bound=0.018, batch=227
# 698: loss=0.927, reward_mean=0.090, reward_bound=0.342, batch=229
# 699: loss=0.928, reward_mean=0.060, reward_bound=0.349, batch=227
# 700: loss=0.930, reward_mean=0.090, reward_bound=0.387, batch=221
# 701: loss=0.929, reward_mean=0.040, reward_bound=0.185, batch=224
# 702: loss=0.929, reward_mean=0.080, reward_bound=0.254, batch=226
# 703: loss=0.927, reward_mean=0.080, reward_bound=0.351, batch=228
# 704: loss=0.929, reward_mean=0.090, reward_bound=0.387, batch=228
# 705: loss=0.929, reward_mean=0.090, reward_bound=0.392, batch=229
# 706: loss=0.927, reward_mean=0.110, reward_bound=0.430, batch=225
# 707: loss=0.927, reward_mean=0.060, reward_bound=0.329, batch=227
# 708: loss=0.925, reward_mean=0.070, reward_bound=0.387, batch=228
# 709: loss=0.927, reward_mean=0.080, reward_bound=0.397, batch=229
# 710: loss=0.927, reward_mean=0.050, reward_bound=0.424, batch=230
# 711: loss=0.927, reward_mean=0.040, reward_bound=0.418, batch=231
# 712: loss=0.926, reward_mean=0.080, reward_bound=0.430, batch=231
# 713: loss=0.930, reward_mean=0.070, reward_bound=0.478, batch=223
# 714: loss=0.931, reward_mean=0.080, reward_bound=0.398, batch=226
# 715: loss=0.928, reward_mean=0.050, reward_bound=0.298, batch=228
# 716: loss=0.929, reward_mean=0.080, reward_bound=0.430, batch=227
# 717: loss=0.930, reward_mean=0.080, reward_bound=0.314, batch=228
# 718: loss=0.928, reward_mean=0.100, reward_bound=0.387, batch=228
# 719: loss=0.928, reward_mean=0.030, reward_bound=0.314, batch=228
# 720: loss=0.927, reward_mean=0.060, reward_bound=0.297, batch=229
# 721: loss=0.927, reward_mean=0.100, reward_bound=0.430, batch=229
# 722: loss=0.926, reward_mean=0.090, reward_bound=0.478, batch=232
# 723: loss=0.926, reward_mean=0.070, reward_bound=0.445, batch=232
# 724: loss=0.931, reward_mean=0.060, reward_bound=0.478, batch=226
# 725: loss=0.929, reward_mean=0.080, reward_bound=0.387, batch=227
# 726: loss=0.929, reward_mean=0.060, reward_bound=0.356, batch=229
# 727: loss=0.931, reward_mean=0.060, reward_bound=0.430, batch=227
# 728: loss=0.930, reward_mean=0.070, reward_bound=0.469, batch=229
# ...
# 1843: loss=0.696, reward_mean=0.170, reward_bound=0.317, batch=229
# 1844: loss=0.697, reward_mean=0.150, reward_bound=0.349, batch=229
# 1845: loss=0.696, reward_mean=0.190, reward_bound=0.387, batch=224
# 1846: loss=0.697, reward_mean=0.160, reward_bound=0.349, batch=226
# 1847: loss=0.698, reward_mean=0.140, reward_bound=0.409, batch=228
# 1848: loss=0.700, reward_mean=0.230, reward_bound=0.430, batch=221
# 1849: loss=0.700, reward_mean=0.130, reward_bound=0.229, batch=224
# 1850: loss=0.697, reward_mean=0.210, reward_bound=0.387, batch=225
# 1851: loss=0.699, reward_mean=0.190, reward_bound=0.396, batch=227
# 1852: loss=0.697, reward_mean=0.100, reward_bound=0.342, batch=229
# 1853: loss=0.700, reward_mean=0.140, reward_bound=0.328, batch=230
# 1854: loss=0.695, reward_mean=0.230, reward_bound=0.430, batch=229
# 1855: loss=0.693, reward_mean=0.140, reward_bound=0.405, batch=230
# 1856: loss=0.692, reward_mean=0.150, reward_bound=0.338, batch=231
# 1857: loss=0.692, reward_mean=0.170, reward_bound=0.349, batch=231
# 1858: loss=0.695, reward_mean=0.210, reward_bound=0.430, batch=231
# 1859: loss=0.695, reward_mean=0.170, reward_bound=0.478, batch=200
# 1860: loss=0.688, reward_mean=0.190, reward_bound=0.194, batch=210
# 1861: loss=0.686, reward_mean=0.160, reward_bound=0.185, batch=216
# 1862: loss=0.680, reward_mean=0.190, reward_bound=0.206, batch=219
# 1863: loss=0.677, reward_mean=0.160, reward_bound=0.239, batch=223
# 1864: loss=0.681, reward_mean=0.170, reward_bound=0.282, batch=225
# 1865: loss=0.691, reward_mean=0.160, reward_bound=0.314, batch=221
# 1866: loss=0.686, reward_mean=0.200, reward_bound=0.349, batch=221
# 1867: loss=0.686, reward_mean=0.210, reward_bound=0.349, batch=224
# 1868: loss=0.691, reward_mean=0.190, reward_bound=0.387, batch=220
# 1869: loss=0.683, reward_mean=0.190, reward_bound=0.304, batch=224
# 1870: loss=0.691, reward_mean=0.140, reward_bound=0.308, batch=227
# 1871: loss=0.694, reward_mean=0.160, reward_bound=0.342, batch=229
# 1872: loss=0.695, reward_mean=0.160, reward_bound=0.349, batch=229
# 1873: loss=0.696, reward_mean=0.120, reward_bound=0.387, batch=227
# 1874: loss=0.690, reward_mean=0.150, reward_bound=0.430, batch=220
# 1875: loss=0.688, reward_mean=0.160, reward_bound=0.296, batch=224
# 1876: loss=0.686, reward_mean=0.140, reward_bound=0.345, batch=227
# 1877: loss=0.686, reward_mean=0.190, reward_bound=0.380, batch=229
# 1878: loss=0.684, reward_mean=0.150, reward_bound=0.387, batch=226
# 1879: loss=0.681, reward_mean=0.190, reward_bound=0.368, batch=228
# 1880: loss=0.684, reward_mean=0.230, reward_bound=0.430, batch=226
# 1881: loss=0.682, reward_mean=0.180, reward_bound=0.356, batch=228
# 1882: loss=0.683, reward_mean=0.100, reward_bound=0.353, batch=229
# 1883: loss=0.682, reward_mean=0.160, reward_bound=0.430, batch=229
# 1884: loss=0.683, reward_mean=0.200, reward_bound=0.478, batch=232
# 1885: loss=0.687, reward_mean=0.160, reward_bound=0.478, batch=213
# 1886: loss=0.679, reward_mean=0.110, reward_bound=0.190, batch=219
# 1887: loss=0.679, reward_mean=0.170, reward_bound=0.282, batch=222
# 1888: loss=0.675, reward_mean=0.140, reward_bound=0.349, batch=222
# 1889: loss=0.675, reward_mean=0.140, reward_bound=0.336, batch=225
# 1890: loss=0.676, reward_mean=0.130, reward_bound=0.349, batch=226
# 1891: loss=0.694, reward_mean=0.220, reward_bound=0.430, batch=220
# 1892: loss=0.693, reward_mean=0.170, reward_bound=0.338, batch=224
# 1893: loss=0.690, reward_mean=0.180, reward_bound=0.384, batch=227
# 1894: loss=0.690, reward_mean=0.130, reward_bound=0.373, batch=229
# 1895: loss=0.690, reward_mean=0.120, reward_bound=0.364, batch=230
# 1896: loss=0.691, reward_mean=0.250, reward_bound=0.387, batch=227
# 1897: loss=0.692, reward_mean=0.240, reward_bound=0.430, batch=224
# 1898: loss=0.691, reward_mean=0.130, reward_bound=0.311, batch=227
# 1899: loss=0.693, reward_mean=0.150, reward_bound=0.380, batch=229
# 1900: loss=0.695, reward_mean=0.150, reward_bound=0.387, batch=229
# 1901: loss=0.696, reward_mean=0.170, reward_bound=0.324, batch=230
# 1902: loss=0.696, reward_mean=0.170, reward_bound=0.418, batch=231
# 1903: loss=0.691, reward_mean=0.160, reward_bound=0.430, batch=230
# 1904: loss=0.692, reward_mean=0.210, reward_bound=0.451, batch=231
# 1905: loss=0.692, reward_mean=0.070, reward_bound=0.314, batch=231
# 1906: loss=0.692, reward_mean=0.160, reward_bound=0.478, batch=221
# 1907: loss=0.693, reward_mean=0.180, reward_bound=0.254, batch=224
# 1908: loss=0.692, reward_mean=0.130, reward_bound=0.254, batch=226
# 1909: loss=0.694, reward_mean=0.150, reward_bound=0.349, batch=226
# 1910: loss=0.692, reward_mean=0.160, reward_bound=0.368, batch=228
# 1911: loss=0.693, reward_mean=0.130, reward_bound=0.387, batch=227
# 1912: loss=0.693, reward_mean=0.110, reward_bound=0.422, batch=229
# 1913: loss=0.693, reward_mean=0.140, reward_bound=0.265, batch=230
# 1914: loss=0.697, reward_mean=0.160, reward_bound=0.430, batch=226
# 1915: loss=0.696, reward_mean=0.230, reward_bound=0.433, batch=228
# 1916: loss=0.698, reward_mean=0.150, reward_bound=0.435, batch=229
# 1917: loss=0.700, reward_mean=0.090, reward_bound=0.364, batch=230
# 1918: loss=0.701, reward_mean=0.110, reward_bound=0.376, batch=231
# 1919: loss=0.701, reward_mean=0.140, reward_bound=0.430, batch=231
# 1920: loss=0.690, reward_mean=0.170, reward_bound=0.478, batch=223
# 1921: loss=0.688, reward_mean=0.110, reward_bound=0.254, batch=225
# 1922: loss=0.686, reward_mean=0.200, reward_bound=0.314, batch=226
# 1923: loss=0.691, reward_mean=0.220, reward_bound=0.409, batch=228
# 1924: loss=0.686, reward_mean=0.210, reward_bound=0.430, batch=228
# 1925: loss=0.687, reward_mean=0.170, reward_bound=0.478, batch=230
# 1926: loss=0.686, reward_mean=0.170, reward_bound=0.376, batch=231
# 1927: loss=0.689, reward_mean=0.150, reward_bound=0.430, batch=231
# 1928: loss=0.687, reward_mean=0.160, reward_bound=0.478, batch=227
# 1929: loss=0.685, reward_mean=0.200, reward_bound=0.342, batch=229
# 1930: loss=0.685, reward_mean=0.170, reward_bound=0.364, batch=230
# 1931: loss=0.689, reward_mean=0.180, reward_bound=0.387, batch=229
# 1932: loss=0.688, reward_mean=0.190, reward_bound=0.405, batch=230
# 1933: loss=0.687, reward_mean=0.180, reward_bound=0.430, batch=230
# 1934: loss=0.688, reward_mean=0.110, reward_bound=0.418, batch=231
# 1935: loss=0.687, reward_mean=0.090, reward_bound=0.430, batch=230
# 1936: loss=0.687, reward_mean=0.110, reward_bound=0.464, batch=231
# 1937: loss=0.687, reward_mean=0.180, reward_bound=0.478, batch=229
# 1938: loss=0.690, reward_mean=0.110, reward_bound=0.471, batch=230
# 1940: loss=0.497, reward_mean=0.090, reward_bound=0.000, batch=9
# 1941: loss=0.554, reward_mean=0.140, reward_bound=0.000, batch=23
# 1942: loss=0.583, reward_mean=0.190, reward_bound=0.000, batch=42
# 1943: loss=0.576, reward_mean=0.100, reward_bound=0.000, batch=52
# 1944: loss=0.586, reward_mean=0.170, reward_bound=0.000, batch=69
# 1945: loss=0.581, reward_mean=0.160, reward_bound=0.000, batch=85
# 1946: loss=0.582, reward_mean=0.200, reward_bound=0.000, batch=105
# 1947: loss=0.579, reward_mean=0.160, reward_bound=0.000, batch=121
# 1948: loss=0.569, reward_mean=0.280, reward_bound=0.000, batch=149
# 1949: loss=0.571, reward_mean=0.160, reward_bound=0.000, batch=165
# 1950: loss=0.562, reward_mean=0.280, reward_bound=0.008, batch=184
# 1951: loss=0.550, reward_mean=0.240, reward_bound=0.028, batch=199
# 1952: loss=0.544, reward_mean=0.210, reward_bound=0.032, batch=209
# 1953: loss=0.539, reward_mean=0.250, reward_bound=0.040, batch=216
# 1954: loss=0.544, reward_mean=0.230, reward_bound=0.058, batch=219
# 1955: loss=0.548, reward_mean=0.210, reward_bound=0.080, batch=220
# 1956: loss=0.545, reward_mean=0.160, reward_bound=0.089, batch=220
# 1957: loss=0.545, reward_mean=0.290, reward_bound=0.118, batch=224
# 1958: loss=0.551, reward_mean=0.280, reward_bound=0.135, batch=217
# 1959: loss=0.558, reward_mean=0.280, reward_bound=0.150, batch=209
# 1960: loss=0.559, reward_mean=0.280, reward_bound=0.157, batch=216
# 1961: loss=0.562, reward_mean=0.150, reward_bound=0.167, batch=207
# 1962: loss=0.568, reward_mean=0.240, reward_bound=0.185, batch=202
# 1963: loss=0.565, reward_mean=0.260, reward_bound=0.206, batch=216
# 1964: loss=0.559, reward_mean=0.210, reward_bound=0.206, batch=205
# 1965: loss=0.556, reward_mean=0.280, reward_bound=0.175, batch=213
# 1966: loss=0.556, reward_mean=0.210, reward_bound=0.206, batch=218
# 1967: loss=0.555, reward_mean=0.240, reward_bound=0.208, batch=222
# 1968: loss=0.537, reward_mean=0.250, reward_bound=0.229, batch=202
# 1969: loss=0.538, reward_mean=0.210, reward_bound=0.155, batch=211
# 1970: loss=0.538, reward_mean=0.230, reward_bound=0.167, batch=216
# 1971: loss=0.539, reward_mean=0.270, reward_bound=0.229, batch=219
# 1972: loss=0.538, reward_mean=0.200, reward_bound=0.254, batch=192
# 1973: loss=0.543, reward_mean=0.240, reward_bound=0.135, batch=204
# 1974: loss=0.546, reward_mean=0.220, reward_bound=0.185, batch=211
# 1975: loss=0.546, reward_mean=0.190, reward_bound=0.185, batch=217
# 1976: loss=0.544, reward_mean=0.320, reward_bound=0.229, batch=218
# 1977: loss=0.540, reward_mean=0.210, reward_bound=0.254, batch=219
# 1978: loss=0.545, reward_mean=0.300, reward_bound=0.282, batch=188
# 1979: loss=0.548, reward_mean=0.290, reward_bound=0.152, batch=201
# 1980: loss=0.544, reward_mean=0.160, reward_bound=0.122, batch=209
# 1981: loss=0.544, reward_mean=0.240, reward_bound=0.167, batch=215
# 1982: loss=0.545, reward_mean=0.260, reward_bound=0.206, batch=217
# 1983: loss=0.540, reward_mean=0.310, reward_bound=0.229, batch=221
# 1984: loss=0.538, reward_mean=0.290, reward_bound=0.282, batch=219
# 1985: loss=0.532, reward_mean=0.230, reward_bound=0.182, batch=223
# 1986: loss=0.535, reward_mean=0.220, reward_bound=0.301, batch=226
# 1987: loss=0.547, reward_mean=0.280, reward_bound=0.314, batch=178
# 1988: loss=0.528, reward_mean=0.190, reward_bound=0.028, batch=194
# 1989: loss=0.546, reward_mean=0.290, reward_bound=0.098, batch=204
# 1990: loss=0.540, reward_mean=0.290, reward_bound=0.150, batch=211
# 1991: loss=0.531, reward_mean=0.250, reward_bound=0.185, batch=216
# 1992: loss=0.541, reward_mean=0.240, reward_bound=0.206, batch=218
# 1993: loss=0.539, reward_mean=0.250, reward_bound=0.229, batch=214
# 1994: loss=0.545, reward_mean=0.200, reward_bound=0.229, batch=219
# 1995: loss=0.542, reward_mean=0.230, reward_bound=0.254, batch=215
# 1996: loss=0.537, reward_mean=0.300, reward_bound=0.282, batch=215
# 1997: loss=0.533, reward_mean=0.210, reward_bound=0.206, batch=219
# 1998: loss=0.533, reward_mean=0.170, reward_bound=0.182, batch=223
# 1999: loss=0.536, reward_mean=0.220, reward_bound=0.282, batch=224
# 2000: loss=0.538, reward_mean=0.220, reward_bound=0.280, batch=227
# 2001: loss=0.536, reward_mean=0.200, reward_bound=0.314, batch=218
# 2002: loss=0.536, reward_mean=0.250, reward_bound=0.257, batch=222
# 2003: loss=0.538, reward_mean=0.220, reward_bound=0.324, batch=225
# 2004: loss=0.537, reward_mean=0.270, reward_bound=0.349, batch=170
# 2005: loss=0.519, reward_mean=0.210, reward_bound=0.006, batch=189
# 2006: loss=0.519, reward_mean=0.230, reward_bound=0.029, batch=202
# 2007: loss=0.522, reward_mean=0.250, reward_bound=0.098, batch=210
# 2008: loss=0.519, reward_mean=0.290, reward_bound=0.150, batch=215
# 2009: loss=0.511, reward_mean=0.300, reward_bound=0.185, batch=217
# 2010: loss=0.509, reward_mean=0.180, reward_bound=0.147, batch=222
# 2011: loss=0.509, reward_mean=0.230, reward_bound=0.191, batch=225
# 2012: loss=0.506, reward_mean=0.250, reward_bound=0.210, batch=227
# 2013: loss=0.509, reward_mean=0.240, reward_bound=0.229, batch=226
# 2014: loss=0.518, reward_mean=0.260, reward_bound=0.254, batch=218
# 2015: loss=0.522, reward_mean=0.240, reward_bound=0.282, batch=214
# 2016: loss=0.521, reward_mean=0.270, reward_bound=0.311, batch=220
# 2017: loss=0.519, reward_mean=0.210, reward_bound=0.247, batch=224
# 2018: loss=0.523, reward_mean=0.220, reward_bound=0.308, batch=227
# 2019: loss=0.524, reward_mean=0.230, reward_bound=0.308, batch=229
# 2020: loss=0.520, reward_mean=0.200, reward_bound=0.314, batch=221
# 2021: loss=0.528, reward_mean=0.220, reward_bound=0.349, batch=213
# 2022: loss=0.527, reward_mean=0.290, reward_bound=0.229, batch=218
# 2023: loss=0.526, reward_mean=0.210, reward_bound=0.257, batch=222
# 2024: loss=0.523, reward_mean=0.210, reward_bound=0.314, batch=221
# 2025: loss=0.526, reward_mean=0.310, reward_bound=0.349, batch=222
# 2026: loss=0.527, reward_mean=0.250, reward_bound=0.360, batch=225
# 2027: loss=0.525, reward_mean=0.220, reward_bound=0.254, batch=226
# 2028: loss=0.537, reward_mean=0.200, reward_bound=0.387, batch=149
# 2029: loss=0.515, reward_mean=0.210, reward_bound=0.000, batch=170
# 2030: loss=0.503, reward_mean=0.270, reward_bound=0.019, batch=189
# 2031: loss=0.503, reward_mean=0.220, reward_bound=0.028, batch=201
# 2032: loss=0.501, reward_mean=0.280, reward_bound=0.052, batch=209
# 2033: loss=0.508, reward_mean=0.180, reward_bound=0.072, batch=212
# 2034: loss=0.509, reward_mean=0.220, reward_bound=0.113, batch=218
# 2035: loss=0.516, reward_mean=0.280, reward_bound=0.167, batch=221
# 2036: loss=0.518, reward_mean=0.220, reward_bound=0.185, batch=224
# 2037: loss=0.522, reward_mean=0.250, reward_bound=0.206, batch=224
# 2038: loss=0.516, reward_mean=0.260, reward_bound=0.229, batch=220
# 2039: loss=0.524, reward_mean=0.340, reward_bound=0.254, batch=215
# 2040: loss=0.522, reward_mean=0.230, reward_bound=0.185, batch=219
# 2041: loss=0.526, reward_mean=0.230, reward_bound=0.282, batch=212
# 2042: loss=0.529, reward_mean=0.310, reward_bound=0.314, batch=206
# 2043: loss=0.526, reward_mean=0.260, reward_bound=0.230, batch=214
# 2044: loss=0.524, reward_mean=0.280, reward_bound=0.165, batch=220
# 2045: loss=0.521, reward_mean=0.220, reward_bound=0.180, batch=224
# 2046: loss=0.518, reward_mean=0.220, reward_bound=0.254, batch=225
# 2047: loss=0.520, reward_mean=0.250, reward_bound=0.282, batch=225
# 2048: loss=0.522, reward_mean=0.230, reward_bound=0.314, batch=223
# 2049: loss=0.523, reward_mean=0.230, reward_bound=0.252, batch=226
# 2050: loss=0.524, reward_mean=0.270, reward_bound=0.331, batch=228
# 2051: loss=0.517, reward_mean=0.220, reward_bound=0.349, batch=217
# 2052: loss=0.511, reward_mean=0.250, reward_bound=0.202, batch=222
# 2053: loss=0.519, reward_mean=0.190, reward_bound=0.282, batch=224
# 2054: loss=0.522, reward_mean=0.230, reward_bound=0.314, batch=226
# 2055: loss=0.520, reward_mean=0.190, reward_bound=0.316, batch=228
# 2056: loss=0.519, reward_mean=0.230, reward_bound=0.349, batch=227
# 2057: loss=0.520, reward_mean=0.250, reward_bound=0.387, batch=205
# 2058: loss=0.519, reward_mean=0.250, reward_bound=0.131, batch=213
# 2059: loss=0.522, reward_mean=0.270, reward_bound=0.220, batch=219
# 2060: loss=0.525, reward_mean=0.230, reward_bound=0.229, batch=222
# 2061: loss=0.522, reward_mean=0.290, reward_bound=0.292, batch=225
# 2062: loss=0.535, reward_mean=0.260, reward_bound=0.314, batch=223
# 2063: loss=0.535, reward_mean=0.240, reward_bound=0.349, batch=225
# 2064: loss=0.533, reward_mean=0.210, reward_bound=0.329, batch=227
# 2065: loss=0.532, reward_mean=0.250, reward_bound=0.292, batch=229
# 2066: loss=0.531, reward_mean=0.140, reward_bound=0.295, batch=230
# 2067: loss=0.530, reward_mean=0.310, reward_bound=0.387, batch=224
# 2068: loss=0.533, reward_mean=0.260, reward_bound=0.426, batch=227
# 2069: loss=0.520, reward_mean=0.160, reward_bound=0.430, batch=113
# 2070: loss=0.495, reward_mean=0.200, reward_bound=0.000, batch=133
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-37c9b6f394d0> in <module>
#      19     full_batch = []
#      20
# ---> 21     for iter_no, batch in enumerate(iterate_batches(env, net, BATCH_SIZE)):
#      22         reward_mean = float(np.mean(list(map(lambda s : s.reward, batch))))
#      23
#
# <ipython-input-6-0a01f2a10217> in iterate_batches(env, net, batch_size)
#      11         act_probs_v = sm(net(obs_v))
#      12         act_probs = act_probs_v.data.numpy()[0]
# ---> 13         action = np.random.choice(len(act_probs), p=act_probs)
#      14
#      15         next_obs, reward, is_done, _ = env.step(action)
#
# KeyboardInterrupt:

# %% [markdown]
# ## - 결과
# <img src = "./image/4/t-3.png">
#
# - 이 전의 frozen lake 환경 보다 성능이 좋아짐
# - 성공 에피소드의 55%정도에서 발전을 멈춤
# - cross-entropy의 규제(regularization) 등을 통해 다룰 수 있지만 앞으로 배울 예정

# %% [markdown]
# #### - "미끄러움"의 영향
# - 각 행동은 33%의 확률로 90도 회전한 행동을 할 수 있음
#     - 위의 행동은 33%의 확률로 위, 33%의 왁률로 왼쪽, 33%의 확률로 오른쪽 으로 행동함
# - 미끄러움 여부는 환경 생성 시 설정 가능
# - 안미끄러운 버전은 미끄러운 버전보다 100배 빠른  성공 성능을 보임

# %% [markdown]
# ### - 결론
# #### cross entropy 방법
# - 현재의 정책을 사용하여 에피소드를 샘플링
# - 가장 성공적인 샘플과 우리의 정책에 대하여 negative log likelihood를 최소화
