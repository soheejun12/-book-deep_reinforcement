# %%
import random
import gym
import gym.spaces

import gym.wrappers
import gym.envs.toy_text.frozen_lake

from collections import namedtuple
import numpy as np
from tensorboardX import SummaryWriter

import torch
import torch.nn as nn
import torch.optim as optim

# %%
HIDDEN_SIZE = 128
BATCH_SIZE = 100
PERCENTILE = 30
GAMMA = 0.9

# %%
class DiscreteOneHotWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super(DiscreteOneHotWrapper, self).__init__(env)
        assert isinstance(env.observation_space, gym.spaces.Discrete)
        self.observation_space = gym.spaces.Box(0.0, 1.0, (env.observation_space.n, ), dtype=np.float32)

    def observation(self, observation):
        res = np.copy(self.observation_space.low)
        res[observation] = 1.0
        return res

# %%
class Net(nn.Module):
    def __init__(self, obs_size, hidden_size, n_actions):
        super(Net, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions)
        )

    def forward(self, x):
        return self.net(x)

# %%
Episode = namedtuple('Episode', field_names=['reward', 'steps'])
EpisodeStep = namedtuple('EpisodeStep', field_names=['observation', 'action'])

# %%
def iterate_batches(env, net, batch_size):
    batch = []
    episode_reward = 0.0
    episode_steps = []
    obs = env.reset()
    sm = nn.Softmax(dim=1)
    while True:
        obs_v = torch.FloatTensor([obs])
        act_probs_v = sm(net(obs_v))
        act_probs = act_probs_v.data.numpy()[0]
        action = np.random.choice(len(act_probs), p=act_probs)
        next_obs, reward, is_done, _ = env.step(action)
        episode_reward += reward
        episode_steps.append(EpisodeStep(observation=obs, action=action))
        if is_done:
            batch.append(Episode(reward=episode_reward, steps=episode_steps))
            episode_reward = 0.0
            episode_steps = []
            next_obs = env.reset()
            if len(batch) == batch_size:
                yield batch
                batch = []
        obs = next_obs

# %%
def filter_batch(batch, percentile):
    disc_rewards = list(map(lambda s: s.reward * (GAMMA ** len(s.steps)), batch))
    reward_bound = np.percentile(disc_rewards, percentile)

    train_obs = []
    train_act = []
    elite_batch = []
    for example, discounted_reward in zip(batch, disc_rewards):
        if discounted_reward > reward_bound:
            train_obs.extend(map(lambda step: step.observation, example.steps))
            train_act.extend(map(lambda step: step.action, example.steps))
            elite_batch.append(example)

    return elite_batch, train_obs, train_act, reward_bound

# %%
if __name__ == "__main__":
    random.seed(12345)
    """nonslippery frozen lake"""
    env = gym.envs.toy_text.frozen_lake.FrozenLakeEnv(is_slippery=False)
    env = gym.wrappers.TimeLimit(env, max_episode_steps=100)
    env = DiscreteOneHotWrapper(env)
    # env = gym.wrappers.Monitor(env, directory="mon", force=True)
    obs_size = env.observation_space.shape[0]
    n_actions = env.action_space.n

    net = Net(obs_size, HIDDEN_SIZE, n_actions)
    objective = nn.CrossEntropyLoss()
    optimizer = optim.Adam(params=net.parameters(), lr=0.001)
    writer = SummaryWriter(comment="-frozenlake-nonslippery")

    full_batch = []
    for iter_no, batch in enumerate(iterate_batches(env, net, BATCH_SIZE)):
        reward_mean = float(np.mean(list(map(lambda s: s.reward, batch))))
        full_batch, obs, acts, reward_bound = filter_batch(full_batch + batch, PERCENTILE)
        if not full_batch:
            continue
        obs_v = torch.FloatTensor(obs)
        acts_v = torch.LongTensor(acts)
        full_batch = full_batch[-500:]

        optimizer.zero_grad()
        action_scores_v = net(obs_v)
        loss_v = objective(action_scores_v, acts_v)
        loss_v.backward()
        optimizer.step()
        print("%d: loss=%.3f, reward_mean=%.3f, reward_bound=%.3f, batch=%d" % (
            iter_no, loss_v.item(), reward_mean, reward_bound, len(full_batch)))
        writer.add_scalar("loss", loss_v.item(), iter_no)
        writer.add_scalar("reward_mean", reward_mean, iter_no)
        writer.add_scalar("reward_bound", reward_bound, iter_no)
        if reward_mean > 0.8:
            print("Solved!")
            break
    writer.close()
# Out:
# 0: loss=1.379, reward_mean=0.020, reward_bound=0.000, batch=2
# 1: loss=1.376, reward_mean=0.020, reward_bound=0.000, batch=4
# 2: loss=1.370, reward_mean=0.020, reward_bound=0.000, batch=6
# 3: loss=1.368, reward_mean=0.010, reward_bound=0.000, batch=7
# 4: loss=1.361, reward_mean=0.010, reward_bound=0.000, batch=8
# 5: loss=1.347, reward_mean=0.040, reward_bound=0.000, batch=12
# 6: loss=1.343, reward_mean=0.040, reward_bound=0.000, batch=16
# 7: loss=1.339, reward_mean=0.020, reward_bound=0.000, batch=18
# 8: loss=1.339, reward_mean=0.040, reward_bound=0.000, batch=22
# 9: loss=1.336, reward_mean=0.000, reward_bound=0.000, batch=22
# 10: loss=1.332, reward_mean=0.040, reward_bound=0.000, batch=26
# 11: loss=1.325, reward_mean=0.030, reward_bound=0.000, batch=29
# 12: loss=1.319, reward_mean=0.020, reward_bound=0.000, batch=31
# 13: loss=1.310, reward_mean=0.040, reward_bound=0.000, batch=35
# 14: loss=1.305, reward_mean=0.020, reward_bound=0.000, batch=37
# 15: loss=1.302, reward_mean=0.080, reward_bound=0.000, batch=45
# 16: loss=1.300, reward_mean=0.020, reward_bound=0.000, batch=47
# 17: loss=1.300, reward_mean=0.040, reward_bound=0.000, batch=51
# 18: loss=1.294, reward_mean=0.020, reward_bound=0.000, batch=53
# 19: loss=1.289, reward_mean=0.010, reward_bound=0.000, batch=54
# 20: loss=1.285, reward_mean=0.010, reward_bound=0.000, batch=55
# 21: loss=1.281, reward_mean=0.060, reward_bound=0.000, batch=61
# 22: loss=1.277, reward_mean=0.040, reward_bound=0.000, batch=65
# 23: loss=1.272, reward_mean=0.060, reward_bound=0.000, batch=71
# 24: loss=1.266, reward_mean=0.020, reward_bound=0.000, batch=73
# 25: loss=1.258, reward_mean=0.040, reward_bound=0.000, batch=77
# 26: loss=1.250, reward_mean=0.090, reward_bound=0.000, batch=86
# 27: loss=1.246, reward_mean=0.070, reward_bound=0.000, batch=93
# 28: loss=1.248, reward_mean=0.060, reward_bound=0.000, batch=99
# 29: loss=1.242, reward_mean=0.060, reward_bound=0.000, batch=105
# 30: loss=1.232, reward_mean=0.100, reward_bound=0.000, batch=115
# 31: loss=1.230, reward_mean=0.070, reward_bound=0.000, batch=122
# 32: loss=1.222, reward_mean=0.140, reward_bound=0.000, batch=136
# 33: loss=1.220, reward_mean=0.070, reward_bound=0.000, batch=143
# 34: loss=1.213, reward_mean=0.070, reward_bound=0.000, batch=150
# 35: loss=1.208, reward_mean=0.070, reward_bound=0.000, batch=157
# 36: loss=1.206, reward_mean=0.090, reward_bound=0.000, batch=166
# 37: loss=1.200, reward_mean=0.100, reward_bound=0.000, batch=176
# 38: loss=1.196, reward_mean=0.120, reward_bound=0.000, batch=188
# 39: loss=1.191, reward_mean=0.110, reward_bound=0.000, batch=199
# 40: loss=1.184, reward_mean=0.110, reward_bound=0.027, batch=209
# 41: loss=1.170, reward_mean=0.120, reward_bound=0.093, batch=216
# 42: loss=1.157, reward_mean=0.100, reward_bound=0.122, batch=218
# 43: loss=1.145, reward_mean=0.120, reward_bound=0.167, batch=218
# 44: loss=1.129, reward_mean=0.100, reward_bound=0.206, batch=212
# 45: loss=1.116, reward_mean=0.140, reward_bound=0.229, batch=209
# 46: loss=1.110, reward_mean=0.110, reward_bound=0.239, batch=216
# 47: loss=1.092, reward_mean=0.110, reward_bound=0.254, batch=208
# 48: loss=1.064, reward_mean=0.190, reward_bound=0.282, batch=192
# 49: loss=1.064, reward_mean=0.120, reward_bound=0.013, batch=204
# 50: loss=1.049, reward_mean=0.220, reward_bound=0.282, batch=211
# 51: loss=1.023, reward_mean=0.200, reward_bound=0.314, batch=192
# 52: loss=1.019, reward_mean=0.180, reward_bound=0.229, batch=202
# 53: loss=1.007, reward_mean=0.200, reward_bound=0.324, batch=211
# 54: loss=0.961, reward_mean=0.160, reward_bound=0.349, batch=172
# 55: loss=0.969, reward_mean=0.170, reward_bound=0.000, batch=189
# 56: loss=0.948, reward_mean=0.220, reward_bound=0.314, batch=199
# 57: loss=0.934, reward_mean=0.210, reward_bound=0.349, batch=200
# 58: loss=0.927, reward_mean=0.220, reward_bound=0.349, batch=208
# 59: loss=0.865, reward_mean=0.180, reward_bound=0.387, batch=153
# 60: loss=0.885, reward_mean=0.220, reward_bound=0.000, batch=175
# 61: loss=0.864, reward_mean=0.260, reward_bound=0.260, batch=192
# 62: loss=0.843, reward_mean=0.320, reward_bound=0.349, batch=197
# 63: loss=0.838, reward_mean=0.220, reward_bound=0.342, batch=208
# 64: loss=0.822, reward_mean=0.330, reward_bound=0.387, batch=207
# 65: loss=0.754, reward_mean=0.260, reward_bound=0.430, batch=156
# 66: loss=0.763, reward_mean=0.370, reward_bound=0.368, batch=179
# 67: loss=0.749, reward_mean=0.310, reward_bound=0.387, batch=192
# 68: loss=0.740, reward_mean=0.280, reward_bound=0.400, batch=204
# 69: loss=0.717, reward_mean=0.300, reward_bound=0.430, batch=198
# 70: loss=0.708, reward_mean=0.330, reward_bound=0.478, batch=211
# 71: loss=0.618, reward_mean=0.420, reward_bound=0.478, batch=126
# 72: loss=0.669, reward_mean=0.290, reward_bound=0.000, batch=155
# 73: loss=0.650, reward_mean=0.360, reward_bound=0.349, batch=177
# 74: loss=0.633, reward_mean=0.280, reward_bound=0.387, batch=190
# 75: loss=0.589, reward_mean=0.350, reward_bound=0.430, batch=186
# 76: loss=0.554, reward_mean=0.350, reward_bound=0.478, batch=174
# 77: loss=0.541, reward_mean=0.400, reward_bound=0.478, batch=185
# 79: loss=0.825, reward_mean=0.440, reward_bound=0.000, batch=44
# 80: loss=0.805, reward_mean=0.330, reward_bound=0.000, batch=77
# 81: loss=0.788, reward_mean=0.480, reward_bound=0.182, batch=124
# 82: loss=0.687, reward_mean=0.520, reward_bound=0.349, batch=150
# 83: loss=0.634, reward_mean=0.530, reward_bound=0.387, batch=169
# 84: loss=0.570, reward_mean=0.520, reward_bound=0.430, batch=154
# 85: loss=0.466, reward_mean=0.480, reward_bound=0.478, batch=107
# 86: loss=0.504, reward_mean=0.480, reward_bound=0.387, batch=139
# 87: loss=0.481, reward_mean=0.500, reward_bound=0.430, batch=160
# 88: loss=0.441, reward_mean=0.580, reward_bound=0.478, batch=166
# 89: loss=0.435, reward_mean=0.470, reward_bound=0.478, batch=182
# 91: loss=0.662, reward_mean=0.560, reward_bound=0.000, batch=56
# 92: loss=0.637, reward_mean=0.470, reward_bound=0.000, batch=103
# 93: loss=0.556, reward_mean=0.510, reward_bound=0.387, batch=134
# 94: loss=0.473, reward_mean=0.560, reward_bound=0.430, batch=134
# 95: loss=0.397, reward_mean=0.490, reward_bound=0.478, batch=109
# 96: loss=0.405, reward_mean=0.540, reward_bound=0.430, batch=143
# 97: loss=0.385, reward_mean=0.610, reward_bound=0.478, batch=158
# 99: loss=0.616, reward_mean=0.580, reward_bound=0.000, batch=58
# 100: loss=0.523, reward_mean=0.560, reward_bound=0.349, batch=109
# 101: loss=0.444, reward_mean=0.530, reward_bound=0.430, batch=126
# 102: loss=0.357, reward_mean=0.650, reward_bound=0.478, batch=109
# 103: loss=0.347, reward_mean=0.640, reward_bound=0.478, batch=145
# 104: loss=0.344, reward_mean=0.620, reward_bound=0.478, batch=168
# 106: loss=0.509, reward_mean=0.710, reward_bound=0.349, batch=69
# 107: loss=0.421, reward_mean=0.650, reward_bound=0.430, batch=104
# 108: loss=0.318, reward_mean=0.560, reward_bound=0.478, batch=105
# 109: loss=0.324, reward_mean=0.720, reward_bound=0.478, batch=140
# 111: loss=0.471, reward_mean=0.650, reward_bound=0.000, batch=65
# 112: loss=0.309, reward_mean=0.760, reward_bound=0.478, batch=86
# 114: loss=0.542, reward_mean=0.600, reward_bound=0.000, batch=60
# 115: loss=0.367, reward_mean=0.680, reward_bound=0.430, batch=101
# 116: loss=0.295, reward_mean=0.740, reward_bound=0.478, batch=121
# 118: loss=0.520, reward_mean=0.610, reward_bound=0.000, batch=61
# 119: loss=0.386, reward_mean=0.770, reward_bound=0.430, batch=110
# 120: loss=0.289, reward_mean=0.750, reward_bound=0.478, batch=132
# 122: loss=0.501, reward_mean=0.710, reward_bound=0.338, batch=70
# 123: loss=0.286, reward_mean=0.800, reward_bound=0.478, batch=106
# 125: loss=0.359, reward_mean=0.850, reward_bound=0.478, batch=79
# Solved!

# %% [markdown]
# ## - 결과
# <img src = "./image/4/ts-3-2.png">
#
# - 훨씬 빠른 속도로 수렴함
